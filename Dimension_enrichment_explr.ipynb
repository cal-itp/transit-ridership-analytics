# %%
import calitp_data_analysis.magics
from google.cloud import bigquery
import pandas as pd
import numpy as np
import re
from datetime import date, timedelta, datetime
import warnings

warnings.filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# #### Get GTFS Data

# %%
client = bigquery.Client()

# %%
sql = """
    SELECT
      dim_entities.schedule_feed_key,
      dim_entities.date,
      dim_entities.organization_name,
      dim_entities.service_name,
      dim_entities.gtfs_dataset_name,
      dim_stop.stop_id,
      dim_stop.stop_code,
      dim_stop.tts_stop_name,
      dim_stop.stop_name,
      dim_stop.stop_lat,
      dim_stop.stop_lon,
      CAST(FROM_BASE64(REPLACE(REPLACE(dim_entities.base64_url, '-', '+'), '_', '/')) AS STRING) AS website
    FROM `mart_gtfs.dim_stops` dim_stop
    JOIN `mart_gtfs.dim_schedule_feeds` dim_schedule
    ON dim_stop.feed_key = dim_schedule.key
    LEFT JOIN `cal-itp-data-infra.staging.int_gtfs_quality__daily_assessment_candidate_entities` dim_entities
    ON dim_stop.feed_key = dim_entities.schedule_feed_key
    WHERE 
    (
      (organization_name = 'City and County of San Francisco' AND service_name = 'Golden Gate Park Shuttle')
      OR
      (organization_name = 'San Mateo County Transit District' AND service_name = 'SamTrans')
      OR
      (organization_name = 'SunLine Transit Agency' AND service_name = 'SunLine Transit')
      -- OR
      -- (organization_name = 'Santa Cruz Metropolitan Transit District' AND service_name = 'Santa Cruz METRO')
      OR
      (organization_name = 'City of Fresno' AND service_name = 'Fresno Area Express')
      OR
      (organization_name = 'San Diego Metropolitan Transit System' AND service_name = 'San Diego Metropolitan Transit System')
      OR
      (organization_name = 'Golden Gate Bridge, Highway and Transportation District' AND service_name = 'Golden Gate Transit')
      -- OR
      -- (organization_name = 'San Francisco Bay Area Rapid Transit District' AND service_name = 'Bay Area Rapid Transit')
      OR
      (organization_name = 'City of Santa Monica' AND service_name = 'Big Blue Bus')
      OR
      (organization_name = 'Long Beach Transit' AND service_name = 'Long Beach Transit')
      OR
      (organization_name = 'OmniTrans' AND service_name = 'OmniTrans')
      OR
      (organization_name = 'Santa Barbara Metropolitan Transit District' AND service_name = 'Santa Barbara Metropolitan Transit District')
      OR
      (organization_name = 'Gold Coast Transit District' AND service_name = 'Gold Coast Transit')
      OR
      (organization_name = 'Sacramento Regional Transit District' AND service_name = 'Sacramento Regional Transit District Bus')
      OR
      (organization_name = 'City of Culver City' AND service_name = 'Culver CityBus')
      OR
      (organization_name = 'Riverside Transit Agency' AND service_name = 'Riverside Transit')
      OR
      (organization_name = 'Orange County Transportation Authority' AND service_name = 'Orange County Transportation Authority')
      OR
      (organization_name = 'Peninsula Corridor Joint Powers Board' AND service_name = 'Caltrain')
    )
    -- AND dim_schedule._is_current = True
    AND gtfs_dataset_type = 'schedule'
    AND gtfs_dataset_name <> "Bay Area 511 Regional Schedule"
    AND DATE = '2026-02-04'
    -- Select data for the most recent date available
    --      DATE = (
    --        SELECT
    --          DATE
    --        FROM
    --          `cal-itp-data-infra.staging.int_gtfs_quality__daily_assessment_candidate_entities`
    --        ORDER BY
    --          DATE DESC
    --        LIMIT
    --          1
    --      )
UNION ALL
SELECT
      dim_entities.schedule_feed_key,
      dim_entities.date,
      dim_entities.organization_name,
      dim_entities.service_name,
      dim_entities.gtfs_dataset_name,
      dim_stop.stop_id,
      dim_stop.stop_code,
      dim_stop.tts_stop_name,
      dim_stop.stop_name,
      dim_stop.stop_lat,
      dim_stop.stop_lon,
      CAST(FROM_BASE64(REPLACE(REPLACE(dim_entities.base64_url, '-', '+'), '_', '/')) AS STRING) AS website,
    FROM `mart_gtfs.dim_stops` dim_stop
    JOIN `mart_gtfs.dim_schedule_feeds` dim_schedule
    ON dim_stop.feed_key = dim_schedule.key
    LEFT JOIN `cal-itp-data-infra.staging.int_gtfs_quality__daily_assessment_candidate_entities` dim_entities
    ON dim_stop.feed_key = dim_entities.schedule_feed_key
    WHERE 
    (
      (organization_name = 'Santa Cruz Metropolitan Transit District' AND service_name = 'Santa Cruz METRO')
    )
    AND gtfs_dataset_type = 'schedule'
    AND DATE = '2026-02-04' -- a version that stop id matches ridership data
UNION ALL
SELECT
      dim_entities.schedule_feed_key,
      dim_entities.date,
      dim_entities.organization_name,
      dim_entities.service_name,
      dim_entities.gtfs_dataset_name,
      dim_stop.stop_id,
      dim_stop.stop_code,
      dim_stop.tts_stop_name,
      dim_stop.stop_name,
      dim_stop.stop_lat,
      dim_stop.stop_lon,
      CAST(FROM_BASE64(REPLACE(REPLACE(dim_entities.base64_url, '-', '+'), '_', '/')) AS STRING) AS website
    FROM `cal-itp-data-infra.mart_gtfs_schedule_latest.dim_stops_latest` dim_stop
    JOIN `mart_gtfs.dim_schedule_feeds` dim_schedule
    ON dim_stop.feed_key = dim_schedule.key
    LEFT JOIN `cal-itp-data-infra.staging.int_gtfs_quality__daily_assessment_candidate_entities` dim_entities
    ON dim_stop.feed_key = dim_entities.schedule_feed_key
    WHERE 
    (
      (organization_name = 'San Francisco Bay Area Rapid Transit District' AND service_name = 'Bay Area Rapid Transit')
    )
    AND gtfs_dataset_name = 'Bay Area 511 BART Schedule'
    AND dim_stop.location_type = 1
    AND dim_schedule._is_current = True
    AND gtfs_dataset_type = 'schedule'
    AND -- Select data for the most recent date available
          DATE = (
            SELECT
              DATE
            FROM
              `cal-itp-data-infra.staging.int_gtfs_quality__daily_assessment_candidate_entities`
            ORDER BY
              DATE DESC
            LIMIT
              1
          )
UNION ALL
SELECT
      dim_entities.schedule_feed_key,
      dim_entities.date,
      dim_entities.organization_name,
      dim_entities.service_name,
      dim_entities.gtfs_dataset_name,
      dim_stop.stop_id,
      dim_stop.stop_code,
      dim_stop.tts_stop_name,
      dim_stop.stop_name,
      dim_stop.stop_lat,
      dim_stop.stop_lon,
      CAST(FROM_BASE64(REPLACE(REPLACE(dim_entities.base64_url, '-', '+'), '_', '/')) AS STRING) AS website,
    FROM `mart_gtfs.dim_stops` dim_stop
    JOIN `mart_gtfs.dim_schedule_feeds` dim_schedule
    ON dim_stop.feed_key = dim_schedule.key
    LEFT JOIN `cal-itp-data-infra.staging.int_gtfs_quality__daily_assessment_candidate_entities` dim_entities
    ON dim_stop.feed_key = dim_entities.schedule_feed_key
    WHERE 
    (
      (organization_name = 'Foothill Transit' AND service_name = 'Foothill Transit')
    )
    AND gtfs_dataset_type = 'schedule'
    AND dim_entities.service_name = "Foothill Transit"
    AND DATE = '2026-02-04'
"""

df_gtfs = client.query(sql).to_dataframe()
df_gtfs.head()
# Out:
#                   schedule_feed_key       date organization_name  \
# 0  540b0c729962003092f3db62a6bbdd12 2026-02-04  Foothill Transit
# 1  540b0c729962003092f3db62a6bbdd12 2026-02-04  Foothill Transit
# 2  540b0c729962003092f3db62a6bbdd12 2026-02-04  Foothill Transit
# 3  540b0c729962003092f3db62a6bbdd12 2026-02-04  Foothill Transit
# 4  540b0c729962003092f3db62a6bbdd12 2026-02-04  Foothill Transit
#
#        service_name  gtfs_dataset_name  stop_id stop_code tts_stop_name  \
# 0  Foothill Transit  Foothill Schedule     1-a1         1          None
# 1  Foothill Transit  Foothill Schedule    10-a1        10          None
# 2  Foothill Transit  Foothill Schedule  1001-a1      1001          None
# 3  Foothill Transit  Foothill Schedule  1002-a1      1002          None
# 4  Foothill Transit  Foothill Schedule  1003-a1      1003          None
#
#                               stop_name      stop_lat        stop_lon  \
# 0     Temple Ave and Diamond Bar Blvd E  34.040203000  -117.798028000
# 1       Orange Grove Ave and Glen Ave N  34.064129000  -117.781042000
# 2  Golden Springs Rd and Calbourne Dr E  33.994209000  -117.858221000
# 3       Colima Rd and Camino del Sur  N  33.977824000  -117.982013000
# 4        Colima Rd and Camino del Sur S  33.978205000  -117.981999000
#
#                                              website
# 0  https://foothill3rdparty.rideralerts.com/mySto...
# 1  https://foothill3rdparty.rideralerts.com/mySto...
# 2  https://foothill3rdparty.rideralerts.com/mySto...
# 3  https://foothill3rdparty.rideralerts.com/mySto...
# 4  https://foothill3rdparty.rideralerts.com/mySto...

# %%
today = date.today().strftime("%Y-%m-%d")
df_gtfs.to_csv(f"GTFS/gtfs_output_{today}.csv", index=False) # save a copy

# %%
# df_gtfs = pd.read_csv("GTFS/gtfs_output_2026-02-05.csv")

# %%
df_gtfs[df_gtfs["organization_name"] == "Santa Cruz Metropolitan Transit District"]
# Out:
#                       schedule_feed_key       date  \
# 26686  02fbd8719f99b906e65b2cf86cbb7cae 2022-12-08
# 26687  02fbd8719f99b906e65b2cf86cbb7cae 2022-12-08
# 26688  02fbd8719f99b906e65b2cf86cbb7cae 2022-12-08
# 26689  02fbd8719f99b906e65b2cf86cbb7cae 2022-12-08
# 26690  02fbd8719f99b906e65b2cf86cbb7cae 2022-12-08
# ...                                 ...        ...
# 27472  02fbd8719f99b906e65b2cf86cbb7cae 2022-12-08
# 27473  02fbd8719f99b906e65b2cf86cbb7cae 2022-12-08
# 27474  02fbd8719f99b906e65b2cf86cbb7cae 2022-12-08
# 27475  02fbd8719f99b906e65b2cf86cbb7cae 2022-12-08
# 27476  02fbd8719f99b906e65b2cf86cbb7cae 2022-12-08
#
#                               organization_name      service_name  \
# 26686  Santa Cruz Metropolitan Transit District  Santa Cruz METRO
# 26687  Santa Cruz Metropolitan Transit District  Santa Cruz METRO
# 26688  Santa Cruz Metropolitan Transit District  Santa Cruz METRO
# 26689  Santa Cruz Metropolitan Transit District  Santa Cruz METRO
# 26690  Santa Cruz Metropolitan Transit District  Santa Cruz METRO
# ...                                         ...               ...
# 27472  Santa Cruz Metropolitan Transit District  Santa Cruz METRO
# 27473  Santa Cruz Metropolitan Transit District  Santa Cruz METRO
# 27474  Santa Cruz Metropolitan Transit District  Santa Cruz METRO
# 27475  Santa Cruz Metropolitan Transit District  Santa Cruz METRO
# 27476  Santa Cruz Metropolitan Transit District  Santa Cruz METRO
#
#          gtfs_dataset_name stop_id stop_code tts_stop_name  \
# 26686  Santa Cruz Schedule   1452R      1452          None
# 26687  Santa Cruz Schedule   1259R      1259          None
# 26688  Santa Cruz Schedule   1712R      1712          None
# 26689  Santa Cruz Schedule   1585R      1585          None
# 26690  Santa Cruz Schedule   1847R      1847          None
# ...                    ...     ...       ...           ...
# 27472  Santa Cruz Schedule   1686R      1686          None
# 27473  Santa Cruz Schedule   2271R      2271          None
# 27474  Santa Cruz Schedule   2160R      2160          None
# 27475  Santa Cruz Schedule   2714R      2714          None
# 27476  Santa Cruz Schedule   1181R      1181          None
#
#                                       stop_name      stop_lat        stop_lon  \
# 26686  Freedom Blvd (Filipino Community Center)  36.946781000  -121.789612000
# 26687                         Broadway & Cayuga  36.975063000  -122.010559000
# 26688           Rio Del Mar Blvd & Clubhouse Dr  36.973217000  -121.888908000
# 26689                    5th Ave (Harbormaster)  36.963802000  -122.000298000
# 26690                 Soquel Dr & W Ledyard Way  36.981739000  -121.910255000
# ...                                         ...           ...             ...
# 27472     Portola Dr & 26th Ave (Trailer Haven)  36.963348000  -121.974937000
# 27473              Broadway & S Branciforte Ave  36.974762000  -122.014656000
# 27474                         38th Ave & Roland  36.966049000  -121.967293000
# 27475                     Holly Dr & Airport Rd  36.931133000  -121.781326000
# 27476                   Airport Blvd & Ross Ave  36.933208000  -121.785034000
#
#                                                  website
# 26686  https://scmtd.com/google_transit/google_transi...
# 26687  https://scmtd.com/google_transit/google_transi...
# 26688  https://scmtd.com/google_transit/google_transi...
# 26689  https://scmtd.com/google_transit/google_transi...
# 26690  https://scmtd.com/google_transit/google_transi...
# ...                                                  ...
# 27472  https://scmtd.com/google_transit/google_transi...
# 27473  https://scmtd.com/google_transit/google_transi...
# 27474  https://scmtd.com/google_transit/google_transi...
# 27475  https://scmtd.com/google_transit/google_transi...
# 27476  https://scmtd.com/google_transit/google_transi...
#
# [791 rows x 12 columns]

# %%
# remove "R" in stop id string for Santa Cruz
df_gtfs.loc[df_gtfs["organization_name"] == "Santa Cruz Metropolitan Transit District", "stop_id"] = df_gtfs.loc[df_gtfs["organization_name"] == "Santa Cruz Metropolitan Transit District", "stop_id"].astype(str).str.strip().str.replace(r"R$", "", regex=True)

# %%
# rename column name
df_gtfs.rename(columns={"stop_id": "gtfs_stop_id",
                        "stop_name": "gtfs_stop_name"}, inplace=True)

# %%
df_gtfs["organization_name"].unique()
# Out:
# array(['Foothill Transit', 'San Mateo County Transit District',
#        'Santa Cruz Metropolitan Transit District',
#        'Gold Coast Transit District', 'City and County of San Francisco',
#        'Long Beach Transit',
#        'San Francisco Bay Area Rapid Transit District',
#        'Santa Barbara Metropolitan Transit District',
#        'Golden Gate Bridge, Highway and Transportation District',
#        'Peninsula Corridor Joint Powers Board',
#        'Orange County Transportation Authority', 'City of Fresno',
#        'City of Santa Monica', 'City of Culver City',
#        'San Diego Metropolitan Transit System',
#        'Riverside Transit Agency', 'Sacramento Regional Transit District',
#        'SunLine Transit Agency', 'OmniTrans'], dtype=object)

# %%
len(df_gtfs["organization_name"].unique())
# Out:
# 19

# %%
set(df_dim["organization_name"].unique())-set(df_gtfs["organization_name"].unique())
# Out:
# set()

# %%
len(df_gtfs[df_gtfs["organization_name"] == "Orange County Transportation Authority"])
# Out:
# 5245

# %%
df_gtfs[df_gtfs["organization_name"] == "Peninsula Corridor Joint Powers Board"].groupby("gtfs_dataset_name").size()
# Out:
# gtfs_dataset_name
# Bay Area 511 Caltrain Schedule    106
# Caltrain Schedule                 106
# dtype: int64

# %% [markdown]
# #### Import ridership data (meta data and ridership data)

# %%
df_dim = pd.read_csv("preprocessed_ridership_output/dataset_metadata.csv")
df_dim.head(3)
# Out:
#          dataset_id                        dataset_name  \
# 0  189FC69D989010FD  golden_gate_park_shuttle_ridership
# 1  957BBF3AD8FC1B44                  samtrans_ridership
# 2  1B1BADA1E00153AF           sunline_transit_ridership
#
#                    organization_name              service_name  \
# 0   City and County of San Francisco  Golden Gate Park Shuttle
# 1  San Mateo County Transit District                  SamTrans
# 2             SunLine Transit Agency           SunLine Transit
#
#   start_date_collected end_date_collected reporting_unit ridership_measure  \
# 0           2024-07-01         2025-06-30            day             daily
# 1           2025-08-01         2025-08-31            day             daily
# 2           2022-07-01         2025-06-30    fiscal_year         avg_daily
#
#   geographic_grain                                              notes  \
# 0             stop  Collected manually by operators. Weekday two v...
# 1        trip_stop  APCs are not NTD-certified and has error rate ...
# 2             stop                                                NaN
#
#    route_id_exists  route_name_exists  direction_exists  stop_id_exists  \
# 0                0                  0                 1               0
# 1                1                  0                 0               1
# 2                0                  0                 0               1
#
#    stop_name_exists  stop_lat_exists  stop_lon_exists  boardings_exists  \
# 0                 1                0                0                 0
# 1                 1                1                1                 1
# 2                 1                1                1                 1
#
#    alightings_exists  ridership_exists
# 0                  0                 1
# 1                  1                 0
# 2                  1                 0

# %%
# agencies that didn't provide lat and lon
org_loc_missing = df_dim[df_dim["stop_lat_exists"] == 0]["organization_name"].tolist()

# agencies that didn't provide stop_id
org_id_missing = df_dim[df_dim["stop_id_exists"] == 0]["organization_name"].tolist()

# both loc and id missing
org_missing_both = set(org_loc_missing) & set(org_id_missing)

# %%
org_loc_missing
# Out:
# ['City and County of San Francisco',
#  'Santa Cruz Metropolitan Transit District',
#  'City of Fresno',
#  'San Diego Metropolitan Transit System',
#  'Golden Gate Bridge, Highway and Transportation District',
#  'San Francisco Bay Area Rapid Transit District',
#  'Long Beach Transit',
#  'OmniTrans',
#  'Santa Barbara Metropolitan Transit District',
#  'City of Culver City',
#  'Orange County Transportation Authority',
#  'Peninsula Corridor Joint Powers Board']

# %%
org_id_missing
# Out:
# ['City and County of San Francisco',
#  'San Francisco Bay Area Rapid Transit District',
#  'OmniTrans',
#  'Peninsula Corridor Joint Powers Board']

# %%
set(org_loc_missing) - set(org_id_missing)
# Out:
# {'City of Culver City',
#  'City of Fresno',
#  'Golden Gate Bridge, Highway and Transportation District',
#  'Long Beach Transit',
#  'Orange County Transportation Authority',
#  'San Diego Metropolitan Transit System',
#  'Santa Barbara Metropolitan Transit District',
#  'Santa Cruz Metropolitan Transit District'}

# %%
df_ridership = pd.read_csv("preprocessed_ridership_output/preprocessed_stop_ridership.csv")
df_ridership.head()
# Out:
# /tmp/ipykernel_502/574220378.py:1: DtypeWarning: Columns (5,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ridership = pd.read_csv("preprocessed_ridership_output/preprocessed_stop_ridership.csv")
#    Unnamed: 0         record_id        dataset_id  \
# 0           0  FF27A73278C43BCE  189FC69D989010FD
# 1           1  31AC9C20F68713A9  189FC69D989010FD
# 2           2  E021D40119E1054C  189FC69D989010FD
# 3           3  B1F06206C22A5484  189FC69D989010FD
# 4           4  5C7966570540D9F0  189FC69D989010FD
#
#                   organization_name              service_name route_id  \
# 0  City and County of San Francisco  Golden Gate Park Shuttle      NaN
# 1  City and County of San Francisco  Golden Gate Park Shuttle      NaN
# 2  City and County of San Francisco  Golden Gate Park Shuttle      NaN
# 3  City and County of San Francisco  Golden Gate Park Shuttle      NaN
# 4  City and County of San Francisco  Golden Gate Park Shuttle      NaN
#
#   route_name direction stop_id             stop_name  stop_lat  stop_lon  \
# 0        NaN       NaN     NaN  Blue Heron Boathouse       NaN       NaN
# 1        NaN       NaN     NaN  Blue Heron Boathouse       NaN       NaN
# 2        NaN       NaN     NaN  Blue Heron Boathouse       NaN       NaN
# 3        NaN       NaN     NaN  Blue Heron Boathouse       NaN       NaN
# 4        NaN       NaN     NaN  Blue Heron Boathouse       NaN       NaN
#
#    daily_boardings  daily_alightings  daily_total_ridership day_type  \
# 0              NaN               NaN                   45.0  weekday
# 1              NaN               NaN                   59.0  weekday
# 2              NaN               NaN                   74.0  weekday
# 3              NaN               NaN                  177.0  weekday
# 4              NaN               NaN                  110.0  weekday
#
#   daily_ridership_basis  start_date    end_date
# 0        reported_daily  2024-07-01  2024-07-01
# 1        reported_daily  2024-07-02  2024-07-02
# 2        reported_daily  2024-07-03  2024-07-03
# 3        reported_daily  2024-07-04  2024-07-04
# 4        reported_daily  2024-07-05  2024-07-05

# %%
# df_ridership["stop_name_norm"] = df_ridership["stop_name"].astype("string").apply(norm_stop_name)
# df_gtfs["gtfs_stop_name_norm"] = df_gtfs["gtfs_stop_name"].apply(norm_stop_name)

# %%
df_ridership["stop_id"] = pd.to_numeric(df_ridership["stop_id"], errors="coerce").astype("Int64").astype("string")
df_ridership["gtfs_stop_id"] = pd.Series(pd.NA, dtype="string")
df_gtfs["gtfs_stop_id"] = df_gtfs["gtfs_stop_id"].astype("string")

# %%
# df_ridership["stop_id_norm"] = df_ridership["stop_id"].str.extract(r"(\d+)", expand=False)

# %%
# mixed_cols = df_ridership.columns[[5,6,7,8]]

# for col in mixed_cols:
#     print(col)
#     print(df_ridership[col].map(type).value_counts())
#     print("\n")

# %% [markdown]
# #### Functions and Vars

# %%
STREET_TYPE_PATTERNS = {
    r"\b(st|st\.|street|stree)\b": "street",
    r"\b(av|av\.|ave|ave\.|avenue)\b": "avenue",
    r"\b(blvd|blvd\.|boulevard)\b": "boulevard",
    r"\b(rd|rd\.|road)\b": "road",
    r"\b(dr|dr\.|drive)\b": "drive",
    r"\b(ln|ln\.|lane)\b": "lane",
    r"\b(pl|pl\.|place)\b": "place",
    r"\b(wy|wy\.|way\.|way)\b": "way",
    r"\b(hwy|hwy\.|highway|highway\.)\b": "highway",
    r"\b(pl|pl\.|place\.)\b": "place",
    r"\b(pkwy|pkwy\.|pkway|parkway\.)\b": "parkway"
}

DIRECTION_PATTERNS = {
    r"\b(e|eb|eastbound)\b": "eastbound",
    r"\b(w|wb|westbound)\b": "westbound",
    r"\b(s|sb|southbound)\b": "southbound",
    r"\b(n|nb|northbound)\b": "northbound"
}

# USE TO REMOVE STREET TYPE WORDS FOR SPECIFIC AGENCIES
STREET_TYPE_WORDS = {"street", "avenue", "road", "boulevard", "drive", "lane", "highway", "way", "place", "route"}
street_type_regex = r"\b(" + "|".join(STREET_TYPE_WORDS) + r")\b"

# %%
# Golden Gate Park Shuttle Stop Name Aliases
GOLDEN_GATE_STOP_ALIASES = {"de young tea garden": "de young museum",
                            "music concourse bandshell": "music concourse",
                            "blue heron lake": "blue heron",
                            "blue heron boathouse": "blue heron",
                            "cal academy": "academy of sciences",
                            "10th avenue de young eastbound": "10th avenue music concourse eastbound",
                            "10th avenue de young westbound": "10th avenue music concourse westbound"}

# %%
# OmniTrans Name Aliases
OMNITRANS_STOP_REPLACEMENTS = {
                            r"\bmed\b": "medical",
                            r"\bctr\b": "center",
                            r"\breg\b": "regional",
                            r"\bhosp\b": "hospital",
                            r"\buni\b": "university",
                            r"\bv\s*a\b": "va",
                            r"\bcal\b": "california"
}
OMNITRANS_STOP_ALIASES = {
                            "medical ctr": "medical center",
                            "reg med ctr": "regional medical center",
                            "california state uni": "california state university",
                            "cal state university sb": "california state university",
                            "sbx kendal shandin hils 40th": "sbx kendall shandin hills",
                            "4th street via tunin": "4th via turin",
                            "v a hospital": "va hospital",
                            "sbx va hospital": "va hospital",
                            "2nd lst": "2nd l street",
                            "archibald ontarioranch": "archibald ontario ranch"
                          }

# %%
CALTRAIN_EXTRA_WORDS = {r"\bstation\b", r"\bcaltrain\b"}

# %%
BART_STOP_ALIASES = {
                        "bayfair": "bay fair",
                        "berryessa north san jose": "berryessa"
                    }

# %%
def norm_street_types(s):
    for pattern, replacement in STREET_TYPE_PATTERNS.items():
        s = s.str.replace(pattern, replacement, regex=True)
    return s

# %%
def norm_direction(s):
    for pattern, replacement in DIRECTION_PATTERNS.items():
        s = s.str.replace(pattern, replacement, regex=True)
    return s

# %%
# normalize stop name
def norm_stop_name(s, org_name):
    s = s.astype("string").str.lower().str.replace(r"\s*\(\d+\)\s*$", "", regex=True) \
         .str.replace(r"\bat\b", " ", regex=True) \
         .str.replace(r"[@/]", " ", regex=True) \
         .str.replace(r"[,\-]", " ", regex=True) \
         .str.replace(r"\s+", " ", regex=True) \
         .str.strip()
        
    s = norm_direction(s)
    s = norm_street_types(s)

    # agency-specific logic
    if org_name == "Peninsula Corridor Joint Powers Board": # for Caltrain
        s = s.str.replace(r"\bcaltrain\b", "", regex=True) \
             .str.replace(r"\bstation\b", "", regex=True) \
             .str.replace(r"\s+", "", regex=True)

    if org_name == "City and County of San Francisco": # for Golden Gate Park Shuttle
        s = s.str.replace(r"\bdalia\b", "dahlia", regex=True)
        s = s.replace(GOLDEN_GATE_STOP_ALIASES)

    if org_name == "OmniTrans":
        # s = s.str.replace(r"\b2nd lst\b", "2nd l street", regex=True)
        for pat, repl in OMNITRANS_STOP_REPLACEMENTS.items():
            s = s.str.replace(pat, repl, regex=True)
        s = s.replace(OMNITRANS_STOP_ALIASES)

    if org_name == "San Francisco Bay Area Rapid Transit District":
        s = s.replace(BART_STOP_ALIASES)
        s = s.str.replace(r"\s*\([^)]*\)\s*", "", regex=True)
        
    return s

# %%
def norm_stop_id(s):
    """Normalize stop id to a numeric string, e.g., 0001 -> 1"""
    return (pd.to_numeric(s, errors="coerce").astype("Int64").astype("string")) # 'abc' -> NA, 00001 -> 1, 1.0 -> 1

# %% [markdown]
# ### Check data come with stop id and compare to GTFS stop id

# %% [markdown]
# If they don't match, map in GTFS stop id (gtfs_stop_id)
#
# Agencies:
# - San Mateo County Transit District (SamTrans)
# - SunLine Transit
# - Foothill Transit (already checked. stop name mapped in from GTFS)
# - City of Santa Monica (Big Blue Bus)
# - Gold Coast Transit District (no stop id and use stop name to map in id, lat/lon from GTFS)
# - Sacramento Regional Transit District (Bus)
# - Riverside Transit Agency (no stop name. stop id ambiguous -> same stop id lat/lon not matched in raw data and GTFS)

# %% [markdown]
# #### SamTrans (Conclusion: match)

# %%
samtrans_ridership = df_ridership[df_ridership["organization_name"] == "San Mateo County Transit District"]
samtrans_gtfs = df_gtfs[df_gtfs["organization_name"] == "San Mateo County Transit District"]

# %%
samtrans_ridership[["stop_id", "stop_name"]].drop_duplicates().sort_values(by="stop_id").head()
# Out:
#       stop_id                       stop_name
# 6652   311010   Terra Nova Blvd & Alicante Dr
# 26656  311013       Bradford Way & Fairway Dr
# 26681  311016  Capistrano Dr & Linda Mar Blvd
# 26740  311018       Capistrano Dr & Rosita Rd
# 9499   311019   Clarendon Rd & Francisco Blvd

# %%
samtrans_gtfs[["gtfs_stop_id", "gtfs_stop_name"]].drop_duplicates().sort_values(by="gtfs_stop_id").head()
# Out:
#       gtfs_stop_id                  gtfs_stop_name
# 13697       311010   Terra Nova Blvd & Alicante Dr
# 13238       311013       Bradford Way & Fairway Dr
# 14698       311016  Capistrano Dr & Linda Mar Blvd
# 13452       311018       Capistrano Dr & Rosita Rd
# 13898       311019   Clarendon Rd & Francisco Blvd

# %% [markdown]
# #### SunLine Transit (Conclusion: match)

# %%
sql = """
 SELECT
      dim_entities.schedule_feed_key,
      dim_entities.date,
      dim_entities.organization_name,
      dim_entities.service_name,
      dim_entities.gtfs_dataset_name,
      dim_stop.stop_id,
      dim_stop.tts_stop_name,
      dim_stop.stop_name,
      dim_stop.stop_lat,
      dim_stop.stop_lon,
      CAST(FROM_BASE64(REPLACE(REPLACE(dim_entities.base64_url, '-', '+'), '_', '/')) AS STRING) AS website
    FROM `cal-itp-data-infra.mart_gtfs_schedule_latest.dim_stops_latest` dim_stop
    JOIN `mart_gtfs.dim_schedule_feeds` dim_schedule
    ON dim_stop.feed_key = dim_schedule.key
    LEFT JOIN `cal-itp-data-infra.staging.int_gtfs_quality__daily_assessment_candidate_entities` dim_entities
    ON dim_stop.feed_key = dim_entities.schedule_feed_key
    WHERE 
      (organization_name = 'SunLine Transit Agency' AND service_name = 'SunLine Transit')
    AND dim_schedule._is_current = True
    AND gtfs_dataset_type = 'schedule'
    AND DATE = "2026-01-06"
"""


sunline_gtfs = client.query(sql).to_dataframe()
sunline_gtfs.head()
# Out:
#                   schedule_feed_key       date       organization_name  \
# 0  33864bc27c1a60427dca4ba0be485c17 2026-01-06  SunLine Transit Agency
# 1  33864bc27c1a60427dca4ba0be485c17 2026-01-06  SunLine Transit Agency
# 2  33864bc27c1a60427dca4ba0be485c17 2026-01-06  SunLine Transit Agency
# 3  33864bc27c1a60427dca4ba0be485c17 2026-01-06  SunLine Transit Agency
# 4  33864bc27c1a60427dca4ba0be485c17 2026-01-06  SunLine Transit Agency
#
#       service_name       gtfs_dataset_name stop_id tts_stop_name  \
# 0  SunLine Transit  SunLine Avail Schedule     114          None
# 1  SunLine Transit  SunLine Avail Schedule     245          None
# 2  SunLine Transit  SunLine Avail Schedule     260          None
# 3  SunLine Transit  SunLine Avail Schedule     420          None
# 4  SunLine Transit  SunLine Avail Schedule     614          None
#
#                          stop_name      stop_lat        stop_lon  \
# 0           Ave 50 at Cesar Chavez  33.685597000  -116.183214000
# 1         Indian Canyon at Baristo  33.820016000  -116.545454000
# 2  Tahquitz Canyon at Calle Encila  33.822989000  -116.543980000
# 3          Golf Center & Avenue 43  33.736418000  -116.199304000
# 4        Gene Autry at Vista Chino  33.845614000  -116.505575000
#
#                                              website
# 0  https://infopoint.sunline.org/InfoPoint/GTFS-Z...
# 1  https://infopoint.sunline.org/InfoPoint/GTFS-Z...
# 2  https://infopoint.sunline.org/InfoPoint/GTFS-Z...
# 3  https://infopoint.sunline.org/InfoPoint/GTFS-Z...
# 4  https://infopoint.sunline.org/InfoPoint/GTFS-Z...

# %%
sunline_ridership = df_ridership[df_ridership["organization_name"] == "SunLine Transit Agency"]
sunline_gtfs = df_gtfs[df_gtfs["organization_name"] == "SunLine Transit Agency"]

# %%
sunline_ridership[["stop_id", "stop_name"]].drop_duplicates().sort_values(by="stop_id").head()
# Out:
#       stop_id        stop_name
# 66381       1      Palm@2Bunch
# 66413      10  PalmCyn@Escuela
# 66697     100    Hwy111@Monroe
# 66701     101  Hwy111@LasPalms
# 66705     102   Hwy111@Clinton

# %%
sunline_gtfs[["stop_id", "stop_name"]].drop_duplicates().sort_values(by="stop_id").head()
# Out:
#     stop_id                   stop_name
# 304       1     Palm at Two Bunch Palms
# 148      10  Palm Canyon at Via Escuela
# 427     100           Hwy 111 at Monroe
# 496     101       Hwy 111 at Las Palmas
# 387    1010      Varner at Harry Oliver

# %% [markdown]
# #### City of Santa Monica (Conclusion: not match)

# %% [markdown]
# Ridership stop id contains negative values, and is not consistent with stop id in GTFS. But stop name and lat/lon match (Big Blue Bus Swiftly schedule)
#
# Map in stop id (gtfs_stop_id) using stop name in the dimension enrichment step.

# %%
big_blue_bus_ridership = df_ridership[df_ridership["organization_name"] == "City of Santa Monica"]
big_blue_bus_gtfs = df_gtfs[df_gtfs["organization_name"] == "City of Santa Monica"]

# %%
big_blue_bus_gtfs.head()
# Out:
#                       schedule_feed_key        date     organization_name  \
# 13554  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13555  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13556  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13557  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13558  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
#
#        service_name              gtfs_dataset_name gtfs_stop_id stop_code  \
# 13554  Big Blue Bus  Big Blue Bus Swiftly Schedule         1433      2887
# 13555  Big Blue Bus  Big Blue Bus Swiftly Schedule           21      1000
# 13556  Big Blue Bus  Big Blue Bus Swiftly Schedule          306      2122
# 13557  Big Blue Bus  Big Blue Bus Swiftly Schedule          589      1254
# 13558  Big Blue Bus  Big Blue Bus Swiftly Schedule          322      1392
#
#       tts_stop_name                              gtfs_stop_name   stop_lat  \
# 13554           NaN                       GLENCOE NB & BEACH FS  33.991587
# 13555           NaN  4TH NB & COLORADO FS (Downtown SM Station)  34.014235
# 13556           NaN                  WESTWOOD SB & ROCHESTER NS  34.056230
# 13557           NaN                        MONTANA WB & 22ND NS  34.038779
# 13558           NaN               SANTA MONICA WB & BERKELEY NS  34.037178
#
#          stop_lon                                          website
# 13554 -118.444392  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13555 -118.492457  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13556 -118.442387  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13557 -118.487155  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13558 -118.469573  https://gtfs.bigbluebus.com/current_swiftly.zip

# %%
big_blue_bus_gtfs["gtfs_dataset_name"].unique()
# Out:
# array(['Big Blue Bus Swiftly Schedule', 'Big Blue Bus Schedule'],
#       dtype=object)

# %%
big_blue_bus_ridership[["stop_id", "stop_name"]].drop_duplicates().sort_values(by="stop_id", ascending=False).head(10)
# Out:
#         stop_id                                  stop_name
# 1375271    9999               LAX/MTC BAY 16 DROP OFF ONLY
# 1372637    9991            LAX/METRO TRANSIT CENTER BAY 16
# 1372596    9990             LAX/METRO TRANSIT CENTER BAY 5
# 1367376     364                            UCLA WYTON DR N
# 1368928     338  FIGUEROA NB/7TH NS (METRO CENTER STATION)
# 1375235    3174                WESTCHESTER WB/SEPULVEDA NS
# 1375853    3173                SAN VICENTE WB/WOODACRES NS
# 1377050    3172                      OLYMPIC WB/STEWART FS
# 1377926    3170  COLORADO WB/17TH FS (17TH ST/SMC STATION)
# 1375852    3169                  SAN VICENTE WB/FOXTAIL NS

# %%
big_blue_bus_ridership[["stop_id", "stop_name"]].drop_duplicates().sort_values(by="stop_id").head(5)
# Out:
#         stop_id                     stop_name
# 1369578     -13              PEARL EB/14TH FS
# 1369564     -14              PEARL WB/14TH NS
# 1369563     -18  SMC BUNDY CAMPUS PARKING LOT
# 1375170     -25            WILSHIRE WB/6TH FS
# 1366782      -4        MAIN NB/WESTMINSTER FS

# %%
big_blue_bus_gtfs[["gtfs_dataset_name", "gtfs_stop_id", "gtfs_stop_name", "stop_lat", "stop_lon"]].drop_duplicates().sort_values(by="gtfs_stop_id", ascending=False).head()
# Out:
#                    gtfs_dataset_name gtfs_stop_id           gtfs_stop_name  \
# 20510          Big Blue Bus Schedule          999        BROADWAY & 6TH ST
# 14319  Big Blue Bus Swiftly Schedule          998  20TH SB & CALIFORNIA NS
# 13830  Big Blue Bus Swiftly Schedule          997  20TH SB & WASHINGTON NS
# 19923          Big Blue Bus Schedule          996  WILSHIRE BLVD & 23RD ST
# 14008  Big Blue Bus Swiftly Schedule          996       20TH SB & IDAHO FS
#
#         stop_lat    stop_lon
# 20510  34.016488 -118.492066
# 14319  34.032886 -118.485056
# 13830  34.034235 -118.486642
# 19923  34.033220 -118.481125
# 14008  34.035146 -118.487702

# %%
big_blue_bus_ridership[big_blue_bus_ridership["stop_name"].str.startswith("SAN VICENTE")][["stop_id", "stop_name"]].drop_duplicates().sort_values(by="stop_name")
# Out:
#         stop_id                     stop_name
# 1375870    1356        SAN VICENTE EB/11TH NS
# 1369538    3003        SAN VICENTE EB/14TH FS
# 1369545    1358        SAN VICENTE EB/17TH NS
# 1369546    1359        SAN VICENTE EB/19TH NS
# 1369547    1361     SAN VICENTE EB/21ST PL NS
# 1369548    1362        SAN VICENTE EB/23RD NS
# 1375875    1363         SAN VICENTE EB/7TH NS
# 1369091    2583       SAN VICENTE EB/ANITA NS
# 1369079    2269    SAN VICENTE EB/AVONDALE NS
# 1367468    2012  SAN VICENTE EB/BARRINGTON NS
# 1369080    2270     SAN VICENTE EB/BRISTOL NS
# 1369078    2265       SAN VICENTE EB/BUNDY NS
# 1367473    2217    SAN VICENTE SB/MAYFIELD FS
# 1369535    3000        SAN VICENTE WB/21ST FS
# 1369534    2999        SAN VICENTE WB/23RD NS
# 1367249    1365         SAN VICENTE WB/7TH FS
# 1369035    2266       SAN VICENTE WB/ANITA NS
# 1369037    2268    SAN VICENTE WB/AVONDALE NS
# 1367519    2013  SAN VICENTE WB/BARRINGTON NS
# 1367521    2218    SAN VICENTE WB/BRINGHAM FS
# 1369036    2267     SAN VICENTE WB/BRISTOL NS
# 1369034    2264       SAN VICENTE WB/BUNDY FS
# 1375852    3169     SAN VICENTE WB/FOXTAIL NS
# 1369537    3002     SAN VICENTE WB/GALE PL NS
# 1369536    3001     SAN VICENTE WB/LA MESA FS
# 1375853    3173   SAN VICENTE WB/WOODACRES NS

# %%
[big_blue_bus_gtfs["gtfs_dataset_name"] == "Big Blue Bus Schedule"]

# %%
big_blue_bus_gtfs[big_blue_bus_gtfs["gtfs_stop_name"].str.startswith("SAN VICENTE")].sort_values(by="gtfs_stop_name")
# Out:
#                       schedule_feed_key        date     organization_name  \
# 19883  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20487  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20396  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20290  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20692  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 19836  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 19937  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 19936  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20026  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20423  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20568  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 19855  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20154  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20207  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 19894  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20140  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20788  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20319  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20573  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 19852  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20453  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20061  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20705  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20049  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20358  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 20696  87622f9dd227481c3659cb63f2896964  2026-02-04  City of Santa Monica
# 14055  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 14368  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13866  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13720  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13712  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 14466  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13769  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 14096  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 14238  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13687  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13840  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 14431  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13616  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 14175  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13695  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 14493  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 14187  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 14343  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 14406  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13662  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 14071  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13707  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13731  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 13911  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 14509  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
# 14407  2ff300f86335c8503b49c43e4e4034c4  2026-02-04  City of Santa Monica
#
#        service_name              gtfs_dataset_name gtfs_stop_id stop_code  \
# 19883  Big Blue Bus          Big Blue Bus Schedule         1049      1356
# 20487  Big Blue Bus          Big Blue Bus Schedule          239      3003
# 20396  Big Blue Bus          Big Blue Bus Schedule          706      1358
# 20290  Big Blue Bus          Big Blue Bus Schedule          707      1359
# 20692  Big Blue Bus          Big Blue Bus Schedule          708      1361
# 19836  Big Blue Bus          Big Blue Bus Schedule          282      3000
# 19937  Big Blue Bus          Big Blue Bus Schedule          709      1362
# 19936  Big Blue Bus          Big Blue Bus Schedule          289      2999
# 20026  Big Blue Bus          Big Blue Bus Schedule         1048      1363
# 20423  Big Blue Bus          Big Blue Bus Schedule          694      1365
# 20568  Big Blue Bus          Big Blue Bus Schedule          690      2266
# 19855  Big Blue Bus          Big Blue Bus Schedule           72      2583
# 20154  Big Blue Bus          Big Blue Bus Schedule          710      2269
# 20207  Big Blue Bus          Big Blue Bus Schedule          692      2268
# 19894  Big Blue Bus          Big Blue Bus Schedule          570      2013
# 20140  Big Blue Bus          Big Blue Bus Schedule          567      2012
# 20788  Big Blue Bus          Big Blue Bus Schedule          644      2218
# 20319  Big Blue Bus          Big Blue Bus Schedule          691      2267
# 20573  Big Blue Bus          Big Blue Bus Schedule          711      2270
# 19852  Big Blue Bus          Big Blue Bus Schedule          689      2265
# 20453  Big Blue Bus          Big Blue Bus Schedule          688      2264
# 20061  Big Blue Bus          Big Blue Bus Schedule         1053      3169
# 20705  Big Blue Bus          Big Blue Bus Schedule          241      3002
# 20049  Big Blue Bus          Big Blue Bus Schedule          283      3001
# 20358  Big Blue Bus          Big Blue Bus Schedule          643      2217
# 20696  Big Blue Bus          Big Blue Bus Schedule         1046      3173
# 14055  Big Blue Bus  Big Blue Bus Swiftly Schedule          671      1356
# 14368  Big Blue Bus  Big Blue Bus Swiftly Schedule         1497      3003
# 13866  Big Blue Bus  Big Blue Bus Swiftly Schedule          673      1358
# 13720  Big Blue Bus  Big Blue Bus Swiftly Schedule          674      1359
# 13712  Big Blue Bus  Big Blue Bus Swiftly Schedule          675      1361
# 14466  Big Blue Bus  Big Blue Bus Swiftly Schedule          676      1362
# 13769  Big Blue Bus  Big Blue Bus Swiftly Schedule          669      1363
# 14096  Big Blue Bus  Big Blue Bus Swiftly Schedule         1151      2583
# 14238  Big Blue Bus  Big Blue Bus Swiftly Schedule          677      2269
# 13687  Big Blue Bus  Big Blue Bus Swiftly Schedule           46      2012
# 13840  Big Blue Bus  Big Blue Bus Swiftly Schedule          678      2270
# 14431  Big Blue Bus  Big Blue Bus Swiftly Schedule          643      2265
# 13616  Big Blue Bus  Big Blue Bus Swiftly Schedule          578      2217
# 14175  Big Blue Bus  Big Blue Bus Swiftly Schedule         1553      3000
# 13695  Big Blue Bus  Big Blue Bus Swiftly Schedule         1560      2999
# 14493  Big Blue Bus  Big Blue Bus Swiftly Schedule          655      1365
# 14187  Big Blue Bus  Big Blue Bus Swiftly Schedule          644      2266
# 14343  Big Blue Bus  Big Blue Bus Swiftly Schedule          646      2268
# 14406  Big Blue Bus  Big Blue Bus Swiftly Schedule           47      2013
# 13662  Big Blue Bus  Big Blue Bus Swiftly Schedule          579      2218
# 14071  Big Blue Bus  Big Blue Bus Swiftly Schedule          645      2267
# 13707  Big Blue Bus  Big Blue Bus Swiftly Schedule          642      2264
# 13731  Big Blue Bus  Big Blue Bus Swiftly Schedule         1726      3169
# 13911  Big Blue Bus  Big Blue Bus Swiftly Schedule         1499      3002
# 14509  Big Blue Bus  Big Blue Bus Swiftly Schedule         1554      3001
# 14407  Big Blue Bus  Big Blue Bus Swiftly Schedule         1731      3173
#
#       tts_stop_name                     gtfs_stop_name   stop_lat    stop_lon  \
# 19883           NaN         SAN VICENTE BLVD & 11TH ST  34.036296 -118.505900
# 20487           NaN         SAN VICENTE BLVD & 14TH ST  34.039819 -118.503631
# 20396           NaN         SAN VICENTE BLVD & 17TH ST  34.041802 -118.501104
# 20290           NaN         SAN VICENTE BLVD & 19TH ST  34.043128 -118.499416
# 20692           NaN      SAN VICENTE BLVD & 21ST PLACE  34.045217 -118.496757
# 19836           NaN         SAN VICENTE BLVD & 21ST ST  34.045568 -118.496829
# 19937           NaN         SAN VICENTE BLVD & 23RD ST  34.046648 -118.494927
# 19936           NaN         SAN VICENTE BLVD & 23RD ST  34.047016 -118.494988
# 20026           NaN          SAN VICENTE BLVD & 7TH ST  34.031772 -118.507958
# 20423           NaN          SAN VICENTE BLVD & 7TH ST  34.031943 -118.508229
# 20568           NaN       SAN VICENTE BLVD & ANITA AVE  34.050807 -118.480555
# 19855           NaN       SAN VICENTE BLVD & ANITA AVE  34.050449 -118.480763
# 20154           NaN    SAN VICENTE BLVD & AVONDALE AVE  34.048680 -118.489729
# 20207           NaN    SAN VICENTE BLVD & AVONDALE AVE  34.049004 -118.489617
# 19894           NaN  SAN VICENTE BLVD & BARRINGTON AVE  34.053792 -118.465613
# 20140           NaN  SAN VICENTE BLVD & BARRINGTON AVE  34.053475 -118.465615
# 20788           NaN    SAN VICENTE BLVD & BRINGHAM AVE  34.054032 -118.462574
# 20319           NaN     SAN VICENTE BLVD & BRISTOL AVE  34.049911 -118.485076
# 20573           NaN     SAN VICENTE BLVD & BRISTOL AVE  34.049539 -118.485396
# 19852           NaN        SAN VICENTE BLVD & BUNDY DR  34.051685 -118.474639
# 20453           NaN        SAN VICENTE BLVD & BUNDY DR  34.051939 -118.474883
# 20061           NaN      SAN VICENTE BLVD & FOXTAIL DR  34.036422 -118.506192
# 20705           NaN      SAN VICENTE BLVD & GALE PLACE  34.041947 -118.501456
# 20049           NaN      SAN VICENTE BLVD & LA MESA DR  34.043324 -118.499690
# 20358           NaN    SAN VICENTE BLVD & MAYFIELD AVE  34.053163 -118.461417
# 20696           NaN    SAN VICENTE BLVD & WOODACRES RD  34.039974 -118.503960
# 14055           NaN           SAN VICENTE EB & 11TH NS  34.036465 -118.505828
# 14368           NaN           SAN VICENTE EB & 14TH FS  34.039780 -118.503742
# 13866           NaN           SAN VICENTE EB & 17TH NS  34.041851 -118.501053
# 13720           NaN           SAN VICENTE EB & 19TH NS  34.043224 -118.499299
# 13712           NaN        SAN VICENTE EB & 21ST PL NS  34.045277 -118.496719
# 14466           NaN           SAN VICENTE EB & 23RD NS  34.046694 -118.494889
# 13769           NaN            SAN VICENTE EB & 7TH NS  34.031871 -118.507812
# 14096           NaN          SAN VICENTE EB & ANITA NS  34.050484 -118.480712
# 14238           NaN       SAN VICENTE EB & AVONDALE NS  34.048698 -118.489667
# 13687           NaN     SAN VICENTE EB & BARRINGTON NS  34.053496 -118.465528
# 13840           NaN        SAN VICENTE EB & BRISTOL NS  34.049582 -118.485261
# 14431           NaN          SAN VICENTE EB & BUNDY NS  34.051729 -118.474473
# 13616           NaN       SAN VICENTE SB & MAYFIELD FS  34.053287 -118.461424
# 14175           NaN           SAN VICENTE WB & 21ST FS  34.045375 -118.497003
# 13695           NaN           SAN VICENTE WB & 23RD NS  34.047016 -118.494988
# 14493           NaN            SAN VICENTE WB & 7TH FS  34.031960 -118.508107
# 14187           NaN          SAN VICENTE WB & ANITA NS  34.050735 -118.480756
# 14343           NaN       SAN VICENTE WB & AVONDALE NS  34.048958 -118.489679
# 14406           NaN     SAN VICENTE WB & BARRINGTON NS  34.053755 -118.465638
# 13662           NaN       SAN VICENTE WB & BRINGHAM FS  34.053948 -118.462244
# 14071           NaN        SAN VICENTE WB & BRISTOL NS  34.049833 -118.485239
# 13707           NaN          SAN VICENTE WB & BUNDY FS  34.051934 -118.474790
# 13731           NaN        SAN VICENTE WB & FOXTAIL NS  34.036422 -118.506191
# 13911           NaN        SAN VICENTE WB & GALE PL NS  34.041878 -118.501478
# 14509           NaN        SAN VICENTE WB & LA MESA FS  34.043348 -118.499616
# 14407           NaN      SAN VICENTE WB & WOODACRES NS  34.039974 -118.503960
#
#                                                website
# 19883      https://www.bigbluebus.com/gtfs/current.zip
# 20487      https://www.bigbluebus.com/gtfs/current.zip
# 20396      https://www.bigbluebus.com/gtfs/current.zip
# 20290      https://www.bigbluebus.com/gtfs/current.zip
# 20692      https://www.bigbluebus.com/gtfs/current.zip
# 19836      https://www.bigbluebus.com/gtfs/current.zip
# 19937      https://www.bigbluebus.com/gtfs/current.zip
# 19936      https://www.bigbluebus.com/gtfs/current.zip
# 20026      https://www.bigbluebus.com/gtfs/current.zip
# 20423      https://www.bigbluebus.com/gtfs/current.zip
# 20568      https://www.bigbluebus.com/gtfs/current.zip
# 19855      https://www.bigbluebus.com/gtfs/current.zip
# 20154      https://www.bigbluebus.com/gtfs/current.zip
# 20207      https://www.bigbluebus.com/gtfs/current.zip
# 19894      https://www.bigbluebus.com/gtfs/current.zip
# 20140      https://www.bigbluebus.com/gtfs/current.zip
# 20788      https://www.bigbluebus.com/gtfs/current.zip
# 20319      https://www.bigbluebus.com/gtfs/current.zip
# 20573      https://www.bigbluebus.com/gtfs/current.zip
# 19852      https://www.bigbluebus.com/gtfs/current.zip
# 20453      https://www.bigbluebus.com/gtfs/current.zip
# 20061      https://www.bigbluebus.com/gtfs/current.zip
# 20705      https://www.bigbluebus.com/gtfs/current.zip
# 20049      https://www.bigbluebus.com/gtfs/current.zip
# 20358      https://www.bigbluebus.com/gtfs/current.zip
# 20696      https://www.bigbluebus.com/gtfs/current.zip
# 14055  https://gtfs.bigbluebus.com/current_swiftly.zip
# 14368  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13866  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13720  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13712  https://gtfs.bigbluebus.com/current_swiftly.zip
# 14466  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13769  https://gtfs.bigbluebus.com/current_swiftly.zip
# 14096  https://gtfs.bigbluebus.com/current_swiftly.zip
# 14238  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13687  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13840  https://gtfs.bigbluebus.com/current_swiftly.zip
# 14431  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13616  https://gtfs.bigbluebus.com/current_swiftly.zip
# 14175  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13695  https://gtfs.bigbluebus.com/current_swiftly.zip
# 14493  https://gtfs.bigbluebus.com/current_swiftly.zip
# 14187  https://gtfs.bigbluebus.com/current_swiftly.zip
# 14343  https://gtfs.bigbluebus.com/current_swiftly.zip
# 14406  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13662  https://gtfs.bigbluebus.com/current_swiftly.zip
# 14071  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13707  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13731  https://gtfs.bigbluebus.com/current_swiftly.zip
# 13911  https://gtfs.bigbluebus.com/current_swiftly.zip
# 14509  https://gtfs.bigbluebus.com/current_swiftly.zip
# 14407  https://gtfs.bigbluebus.com/current_swiftly.zip

# %% [markdown]
# #### Gold Coast Transit District

# %%
gct_ridership = df_ridership[df_ridership["organization_name"] == "Gold Coast Transit District"]
gct_gtfs = df_gtfs[df_gtfs["organization_name"] == "Gold Coast Transit District"]

# %%
gct_ridership[["stop_id", "stop_name"]].drop_duplicates().sort_values(by="stop_id").head(5)
# Out:
#         stop_id       stop_name
# 1401859    <NA>      4th & B St
# 1401863    <NA>      Bard & 5th
# 1401864    <NA>        Bard & C
# 1401866    <NA>     Bard & Park
# 1401868    <NA>  Bard & Saviers

# %% [markdown]
# #### Sacramento Regional Transit District (Conclusion: match)

# %%
sacrt_ridership = df_ridership[df_ridership["organization_name"] == "Sacramento Regional Transit District"]
sacrt_gtfs = df_gtfs[df_gtfs["organization_name"] == "Sacramento Regional Transit District"]

# %%
sacrt_ridership[["stop_id", "stop_name"]].drop_duplicates().sort_values(by="stop_id").head(5)
# Out:
#         stop_id                       stop_name
# 1403361    1000          SLP DR & 43RD AVE (SB)
# 1403362    1001          SLP DR & 43RD AVE (SB)
# 1403363    1002          SLP DR & 47TH AVE (SB)
# 1403364    1003    SLP DR & SILVER LAKE DR (SB)
# 1403797    1004  ANATOLIA DR & HERODIAN DR (NB)

# %%
sacrt_gtfs[["gtfs_stop_id", "gtfs_stop_name", "stop_lat", "stop_lon"]].drop_duplicates().sort_values(by="gtfs_stop_id").head()
# Out:
#       gtfs_stop_id                  gtfs_stop_name   stop_lat    stop_lon
# 28690         1000          SLP DR & 43RD AVE (SB)  38.515701 -121.514778
# 28934         1001          SLP DR & 43RD AVE (SB)  38.513393 -121.515480
# 28075         1002          SLP DR & 47TH AVE (SB)  38.510285 -121.515625
# 27997         1003    SLP DR & SILVER LAKE DR (SB)  38.508082 -121.515010
# 27894         1004  ANATOLIA DR & HERODIAN DR (NB)  38.557220 -121.239525

# %% [markdown]
# #### Riverside Transit Agency

# %%
riverside_ridership = df_ridership[df_ridership["organization_name"] == "Riverside Transit Agency"]
riverside_gtfs = df_gtfs[df_gtfs["organization_name"] == "Riverside Transit Agency"]

# %%
t_df_riverside_ridership = riverside_ridership[["stop_id", "stop_name", "stop_lat", "stop_lon"]].drop_duplicates().sort_values(by="stop_id")

# %%
t_df_riverside_ridership[t_df_riverside_ridership["stop_id"] == '1004']
# Out:
#         stop_id stop_name   stop_lat    stop_lon
# 1791551    1004       NaN  33.880000 -117.594416
# 1507376    1004       NaN  33.879956 -117.594408
# 1606017    1004       NaN  33.983940 -117.594376
# 1409722    1004       NaN  33.879496 -117.594384
# 1508893    1004       NaN  33.880124 -117.594400
# ...         ...       ...        ...         ...
# 1495703    1004       NaN  33.879984 -117.594400
# 1804055    1004       NaN  33.880016 -117.594456
# 1497658    1004       NaN  33.879904 -117.594408
# 1501698    1004       NaN  33.895080 -117.594392
# 1802173    1004       NaN  33.880028 -117.594400
#
# [144 rows x 4 columns]

# %%
riverside_ridership[riverside_ridership["stop_id"] == '1004'].groupby('start_date').size().reset_index(name='count').sort_values(by='count', ascending=False).head()
# Out:
#      start_date  count
# 33   2025-02-04      2
# 96   2025-04-08      2
# 152  2025-07-13      2
# 170  2025-07-31      1
# 175  2025-08-05      1

# %%
riverside_gtfs[["gtfs_stop_id", "gtfs_stop_name", "stop_lat", "stop_lon"]].drop_duplicates().sort_values(by="gtfs_stop_id").head(10)
# Out:
#       gtfs_stop_id               gtfs_stop_name      stop_lat        stop_lon
# 14080           10               Hole + Bayonne  33.917918000  -117.481283000
# 14476          100      Arlington + Yellowstone  33.946387000  -117.394760000
# 13302         1000            Iris + Coachlight  33.893054000  -117.201670000
# 15459         1001          Iris + Grande Vista  33.895258000  -117.195189000
# 14247         1002           Iris + Hammett Ct.  33.895276000  -117.190224000
# 15461         1003                Iris + Oliver  33.895116000  -117.182380000
# 14465         1004  Moreno Beach + Via Del Lago  33.895190000  -117.178521000
# 13148         1005  Moreno Beach + Championship  33.899554000  -117.173933000
# 13157         1006           Moreno Beach + JFK  33.903196000  -117.173829000
# 13053         1007        Moreno Beach + Cactus  33.910595000  -117.173894000

# %% [markdown]
# #### City of Fresno

# %% [markdown]
# Join on stop id to get stop lat/lon

# %%
fresno_mask = df_ridership["organization_name"] == "City of Fresno"

# get gtfs data
df_fresno_gtfs = df_gtfs[df_gtfs["organization_name"] == "City of Fresno"]
df_fresno_gtfs["gtfs_stop_id"] = df_fresno_gtfs["gtfs_stop_id"].astype("int")
df_fresno_gtfs = df_fresno_gtfs.drop_duplicates()

# join on stop id to get lat and lon for Fresno
fresno_joined = df_ridership.loc[fresno_mask].merge(df_fresno_gtfs, 
                                                    left_on=["organization_name", "stop_id"],
                                                    right_on=["organization_name", "gtfs_stop_id"],
                                                    how="left",
                                                    suffixes=("", "_gtfs"))

# fill stop_lat/lon
fresno_joined["stop_lat"] = fresno_joined["stop_lat_gtfs"]
fresno_joined["stop_lon"] = fresno_joined["stop_lon_gtfs"]

# tracking the source of lat/lon
fresno_joined["stop_loc_source"] = "GTFS"

fresno_joined[fresno_joined["organization_name"] == "City of Fresno"].head(3)
# Out:
#    Unnamed: 0         record_id        dataset_id organization_name  \
# 0      766584  FA58B53A0031AFBF  9B106785FD780293    City of Fresno
# 1      766585  B5381368D32E8409  9B106785FD780293    City of Fresno
# 2      766586  010A23E52C281F1D  9B106785FD780293    City of Fresno
#
#           service_name route_id route_name direction stop_id  \
# 0  Fresno Area Express      NaN        NaN       NaN       5
# 1  Fresno Area Express      NaN        NaN       NaN       6
# 2  Fresno Area Express      NaN        NaN       NaN       7
#
#               stop_name  ... date service_name_gtfs  gtfs_dataset_name  \
# 0  NE BRAWLEY - SHIELDS  ...  NaT               NaN                NaN
# 1     SE SHAW - BRAWLEY  ...  NaT               NaN                NaN
# 2        SW SHAW - WEST  ...  NaT               NaN                NaN
#
#    gtfs_stop_id_gtfs  tts_stop_name gtfs_stop_name stop_lat_gtfs  \
# 0                NaN            NaN            NaN           NaN
# 1                NaN            NaN            NaN           NaN
# 2                NaN            NaN            NaN           NaN
#
#   stop_lon_gtfs website stop_loc_source
# 0           NaN     NaN            GTFS
# 1           NaN     NaN            GTFS
# 2           NaN     NaN            GTFS
#
# [3 rows x 31 columns]

# %%
# write back to combined table
df_ridership.loc[fresno_mask, "stop_lat"] = fresno_joined["stop_lat"].values
df_ridership.loc[fresno_mask, "stop_lon"] = fresno_joined["stop_lon"].values
df_ridership.loc[fresno_mask, "stop_loc_source"] = fresno_joined["stop_loc_source"].values

# %%
df_ridership[df_ridership["organization_name"] == "City of Fresno"].head(3)
# Out:
#         Unnamed: 0         record_id        dataset_id organization_name  \
# 766584      766584  FA58B53A0031AFBF  9B106785FD780293    City of Fresno
# 766585      766585  B5381368D32E8409  9B106785FD780293    City of Fresno
# 766586      766586  010A23E52C281F1D  9B106785FD780293    City of Fresno
#
#                service_name route_id route_name direction stop_id  \
# 766584  Fresno Area Express      NaN        NaN       NaN       5
# 766585  Fresno Area Express      NaN        NaN       NaN       6
# 766586  Fresno Area Express      NaN        NaN       NaN       7
#
#                    stop_name  ... stop_lon avg_boardings  avg_alightings  \
# 766584  NE BRAWLEY - SHIELDS  ...      NaN     44.691729       29.748092
# 766585     SE SHAW - BRAWLEY  ...      NaN      7.000000        0.000000
# 766586        SW SHAW - WEST  ...      NaN     20.000000       20.000000
#
#         avg_ridership  day_type agg_basis  start_date    end_date  \
# 766584            NaN   weekend     daily  2024-09-01  2024-09-01
# 766585            NaN   weekend     daily  2024-09-01  2024-09-01
# 766586            NaN   weekend     daily  2024-09-01  2024-09-01
#
#        gtfs_stop_id stop_loc_source
# 766584         <NA>            GTFS
# 766585         <NA>            GTFS
# 766586         <NA>            GTFS
#
# [3 rows x 21 columns]

# %%
fresno_gtfs = df_gtfs[df_gtfs["organization_name"] == "City of Fresno"]
fresno_ridership = df_ridership[df_ridership["organization_name"] == "City of Fresno"]

# %%
fresno_ridership[["stop_id", "stop_name"]].drop_duplicates().sort_values(by="stop_id").head(10)
# Out:
#        stop_id             stop_name
# 766589      10          SHAW - CEDAR
# 767236    1005        SIERRA STATION
# 767237    1009       BARSTOW STATION
# 767238    1017        ASHLAN STATION
# 767239    1018      GRIFFITH STATION
# 767240    1023        WELDON STATION
# 767241    1028       BELMONT STATION
# 767242    1030    NW M ST - MARIPOSA
# 767243    1031    NE E ST - TUOLUMNE
# 767244    1032  NE E ST - STANISLAUS

# %%
fresno_gtfs[["gtfs_stop_id", "gtfs_stop_name"]].drop_duplicates().sort_values(by="gtfs_stop_id").head(10)
# Out:
#       gtfs_stop_id        gtfs_stop_name
# 20033           10       SE Shaw - Cedar
# 19405         1005        Sierra Station
# 19770         1009       Barstow Station
# 19993         1017        Ashlan Station
# 19171         1018      Griffith Station
# 19174         1023        Weldon Station
# 19949         1028       Belmont Station
# 18969         1030    NW M ST - MARIPOSA
# 19639         1031    NE E ST - TUOLUMNE
# 20259         1032  NE E ST - STANISLAUS

# %%
len(fresno_ridership[["stop_id", "stop_name"]].drop_duplicates())
# Out:
# 1618

# %%
len(fresno_gtfs[["gtfs_stop_id", "gtfs_stop_name"]].drop_duplicates())
# Out:
# 1537

# %% [markdown]
# #### Join on hybrid of Stop ID AND Stop Name: Golden Gate Bridge, Highway and Transportation District

# %% [markdown]
# - some stop id consistent with GTFS
# - some stop names match but stop id doesn't match (for example, stop VTP 580 EB @ Toll Plaza, VRBe16 in GTFS, 80016 in dataset provided by agency

# %%
ggt_mask = df_ridership["organization_name"] == "Golden Gate Bridge, Highway and Transportation District"
ggt_ridership = df_ridership.loc[ggt_mask].copy()
ggt_ridership["_orig_index"] = ggt_ridership.index

ggt_gtfs = df_gtfs.loc[df_gtfs["organization_name"] == "Golden Gate Bridge, Highway and Transportation District"].copy()
ggt_gtfs = ggt_gtfs.drop_duplicates()

# %%
ggt_gtfs["gtfs_dataset_name"].unique()
# Out:
# array(['Golden Gate Bridge Schedule',
#        'Bay Area 511 Golden Gate Transit Schedule'], dtype=object)

# %%
ggt_ridership = ggt_ridership[["stop_id", "stop_name"]].drop_duplicates()
ggt_ridership[ggt_ridership["stop_id"].isin(["40039", "40063"])]
# Out:
#         stop_id                           stop_name
# 1328099   40063  Van Ness Ave & Chestnut St (40063)
# 1328135   40039  Van Ness Ave & Chestnut St (40039)

# %%
ggt_gtfs = ggt_gtfs[["date", "schedule_feed_key", "gtfs_dataset_name", "gtfs_stop_id", "gtfs_stop_name"]].drop_duplicates().sort_values(by=["gtfs_stop_id", "gtfs_stop_name"])

# %%
t_ggt_gtfs = ggt_gtfs.groupby(by=["gtfs_stop_name"]).agg(row_count=("gtfs_stop_id", "size"),
                                            unique_count=("gtfs_stop_id", "nunique")).reset_index()
t_ggt_gtfs.sort_values(by="unique_count", ascending=False)
# Out:
#                gtfs_stop_name  row_count  unique_count
# 130   Larkspur Ferry Terminal          6             4
# 177       Paradise Dr Bus Pad          6             3
# 149  Miller Ave & Camino Alto          6             3
# 134      Lucas Valley Bus Pad          6             3
# 135          Lucky Dr Bus Pad          6             3
# ..                        ...        ...           ...
# 39      Bridgeway & Ensign St          2             1
# 37    Bridgeway & Ebbtide Ave          2             1
# 169  North Point St & Polk St          2             1
# 36    Bridgeway & Easterby St          2             1
# 158  Mission St & 2nd St (SF)          2             1
#
# [317 rows x 3 columns]

# %%
ggt_gtfs[ggt_gtfs["gtfs_stop_name"] == "VTP 580 EB Toll Plaza"]
# Out:
#             date                 schedule_feed_key  \
# 2122  2026-02-04  b37bd5e49a60c73f2b1b5631007efa8c
# 2657  2026-02-04  ad8912b0f431700cee4d58efca7489f4
#
#                               gtfs_dataset_name gtfs_stop_id  \
# 2122                Golden Gate Bridge Schedule       VRBe16
# 2657  Bay Area 511 Golden Gate Transit Schedule       VRBe16
#
#              gtfs_stop_name
# 2122  VTP 580 EB Toll Plaza
# 2657  VTP 580 EB Toll Plaza

# %%
t_ggt_gtfs[t_ggt_gtfs["unique_count"] > 1]
# Out:
#                  gtfs_stop_name  row_count  unique_count
# 0              1011 Andersen Dr          4             2
# 4              2nd St & Main St          4             2
# 7                 4th St & C St          4             2
# 8             4th St & Court St          4             2
# 9                 4th St & E St          4             2
# ..                          ...        ...           ...
# 301  Van Ness Ave & Chestnut St          4             2
# 303      Van Ness Ave & Eddy St          4             2
# 310     Van Ness Ave & Union St          4             2
# 311   Van Ness Ave & Vallejo St          4             2
# 316     W Sierra Ave & Water Rd          4             2
#
# [103 rows x 3 columns]

# %%
len(ggt_ridership["stop_id"].drop_duplicates())
# Out:
# 339

# %%
len(ggt_gtfs["gtfs_stop_id"].drop_duplicates())
# Out:
# 440

# %%
ggt_gtfs.head()
# Out:
#                      schedule_feed_key       date  \
# 3273  ad8912b0f431700cee4d58efca7489f4 2026-01-04
# 3275  ad8912b0f431700cee4d58efca7489f4 2026-01-04
# 3276  ad8912b0f431700cee4d58efca7489f4 2026-01-04
# 3278  ad8912b0f431700cee4d58efca7489f4 2026-01-04
# 3279  ad8912b0f431700cee4d58efca7489f4 2026-01-04
#
#                                       organization_name         service_name  \
# 3273  Golden Gate Bridge, Highway and Transportation...  Golden Gate Transit
# 3275  Golden Gate Bridge, Highway and Transportation...  Golden Gate Transit
# 3276  Golden Gate Bridge, Highway and Transportation...  Golden Gate Transit
# 3278  Golden Gate Bridge, Highway and Transportation...  Golden Gate Transit
# 3279  Golden Gate Bridge, Highway and Transportation...  Golden Gate Transit
#
#                               gtfs_dataset_name gtfs_stop_id tts_stop_name  \
# 3273  Bay Area 511 Golden Gate Transit Schedule        lucky          None
# 3275  Bay Area 511 Golden Gate Transit Schedule       sfdgle          None
# 3276  Bay Area 511 Golden Gate Transit Schedule        nspBP          None
# 3278  Bay Area 511 Golden Gate Transit Schedule       sqvile          None
# 3279  Bay Area 511 Golden Gate Transit Schedule       vetmem          None
#
#                               gtfs_stop_name      stop_lat        stop_lon  \
# 3273                        Lucky Dr Bus Pad  37.938327000  -122.516511000
# 3275        Sir Francis Drake Blvd & Glen Dr  38.000177000  -122.603003000
# 3276                  N San Pedro Rd Bus Pad  37.995708000  -122.533433000
# 3278  San Quentin-Francisco Blvd E & Main St  37.943804000  -122.480184000
# 3279         Santa Rosa Veterans Park & Ride  38.433303000  -122.702092000
#
#                                                 website
# 3273  https://api.511.org/transit/datafeeds?operator...
# 3275  https://api.511.org/transit/datafeeds?operator...
# 3276  https://api.511.org/transit/datafeeds?operator...
# 3278  https://api.511.org/transit/datafeeds?operator...
# 3279  https://api.511.org/transit/datafeeds?operator...

# %%
# first join on stop id
ggt_id_join = ggt_ridership.merge(ggt_gtfs, 
                                   left_on = ["stop_id"],
                                   right_on = ["gtfs_stop_id"],
                                   how = "left",
                                   suffixes=("", "_gtfs"))

# join back based on index
df_ridership.loc[ggt_id_join["_orig_index"], ["gtfs_stop_id", "stop_lat", "stop_lon"]] = ggt_id_join[["gtfs_stop_id_gtfs", "stop_lat_gtfs", "stop_lon_gtfs"]].values
# df_ridership.loc[ggt_mask & ggt_matched_id_mask, "gtfs_stop_id"] = ggt_id_join.loc[ggt_matched_id_mask, "gtfs_stop_id"].values
# df_ridership.loc[ggt_mask & ggt_matched_id_mask, "stop_lat_gtfs"] = ggt_id_join.loc[ggt_matched_id_mask, "stop_lat_gtfs"].values
# df_ridership.loc[ggt_mask & ggt_matched_id_mask, "stop_lon_gtfs"] = ggt_id_join.loc[ggt_matched_id_mask, "stop_lon_gtfs"].values

# %%
# normalize stop name
ggt_ridership = df_ridership.loc[ggt_mask].copy()
ggt_ridership["stop_name_norm"] = ggt_ridership["stop_name"].str.replace(r"\s*\(\d+\)\s*$", "", regex=True)
ggt_ridership["stop_name_norm"] = norm_stop_name(ggt_ridership["stop_name_norm"], "Golden Gate Bridge, Highway and Transportation District")
ggt_ridership["_orig_index"] = ggt_ridership.index
need_name_match = ggt_ridership["gtfs_stop_id"].isna() # for those don't have a matched stop id in GTFS

ggt_ridership_name_match = ggt_ridership.loc[need_name_match].copy()

ggt_gtfs["gtfs_stop_name_norm"] = ggt_gtfs["gtfs_stop_name"].str.replace(r"\s*\(\d+\)\s*$", "", regex=True)
ggt_gtfs["gtfs_stop_name_norm"] = norm_stop_name(ggt_gtfs["gtfs_stop_name_norm"], "Golden Gate Bridge, Highway and Transportation District")

# %%
# now join on stop name
ggt_name_join = ggt_ridership_name_match.merge(ggt_gtfs, 
                                   left_on = ["stop_name_norm"],
                                   right_on = ["gtfs_stop_name_norm"],
                                   how = "left",
                                   suffixes=("", "_gtfs"))

df_ridership.loc[ggt_name_join["_orig_index"], ["gtfs_stop_id", "stop_lat", "stop_lon"]] = ggt_name_join[["gtfs_stop_id_gtfs", "stop_lat_gtfs", "stop_lon_gtfs"]].values

# %%
# df_ridership.loc[ggt_mask]

# %%
# df_ggt = df_ridership[df_ridership["organization_name"] == "Golden Gate Bridge, Highway and Transportation District"]
# df_ggt["stop_id"] = df_ggt["stop_id"].astype(int)

# %%
# sorted(df_ggt[df_ggt["stop_id"] > 44113]["stop_name"].unique())

# %%
# df_gtfs[(df_gtfs["organization_name"] == "Golden Gate Bridge, Highway and Transportation District") & (df_gtfs['gtfs_stop_id'] == 'VRBe16')]
# Out:
#                       schedule_feed_key       date  \
# 4843   b2c44a3bf568e82ec60e0f6fd23164a1 2025-12-17
# 11171  7ae439b49a421a190a6d0dd48321b6e2 2025-12-17
#
#                                        organization_name         service_name  \
# 4843   Golden Gate Bridge, Highway and Transportation...  Golden Gate Transit
# 11171  Golden Gate Bridge, Highway and Transportation...  Golden Gate Transit
#
#                                gtfs_dataset_name gtfs_stop_id tts_stop_name  \
# 4843                 Golden Gate Bridge Schedule       VRBe16          None
# 11171  Bay Area 511 Golden Gate Transit Schedule       VRBe16          None
#
#               gtfs_stop_name      stop_lat        stop_lon  \
# 4843   VTP 580 EB Toll Plaza  37.932081000  -122.403886000
# 11171  VTP 580 EB Toll Plaza  37.932081000  -122.403886000
#
#                                                  website
# 4843   https://realtime.goldengate.org/gtfsstatic/GTF...
# 11171  https://api.511.org/transit/datafeeds?operator...

# %% [markdown]
# #### Long Beach Transit

# %% [markdown]
# Map in stop lat and lon using stop id (consistent with GTFS)

# %%
long_beach_ridership = df_ridership[df_ridership["organization_name"] == "Long Beach Transit"]
long_beach_ridership["stop_id"] = long_beach_ridership["stop_id"].astype(int)
long_beach_ridership.head(3)
# Out:
#          Unnamed: 0         record_id        dataset_id   organization_name  \
# 1380222     1380222  D2960CE1EE3757D4  3AF83FABCB03BDF4  Long Beach Transit
# 1380223     1380223  DD1CEC55FB09A920  3AF83FABCB03BDF4  Long Beach Transit
# 1380224     1380224  FD64FA5EA06D8E13  3AF83FABCB03BDF4  Long Beach Transit
#
#                service_name route_id route_name direction  stop_id  \
# 1380222  Long Beach Transit        1        NaN   Inbound     2002
# 1380223  Long Beach Transit        1        NaN   Inbound     2004
# 1380224  Long Beach Transit        1        NaN   Inbound     2006
#
#                        stop_name  stop_lat  stop_lon  avg_boardings  \
# 1380222      2660 Del Amo Blvd S       NaN       NaN       0.000000
# 1380223     Del Amo & Fordyce SW       NaN       NaN       5.977199
# 1380224  Del Amo & Wilmington SW       NaN       NaN       1.890421
#
#          avg_alightings  avg_ridership  day_type    agg_basis  start_date  \
# 1380222        0.000000            NaN  Saturday  fiscal year  2024-07-01
# 1380223        2.219394            NaN  Saturday  fiscal year  2024-07-01
# 1380224        2.872157            NaN  Saturday  fiscal year  2024-07-01
#
#            end_date gtfs_stop_id
# 1380222  2025-06-30         <NA>
# 1380223  2025-06-30         <NA>
# 1380224  2025-06-30         <NA>

# %%
long_beach_ridership[["stop_id", "stop_name"]].drop_duplicates().sort_values(by="stop_id").head()
# Out:
#          stop_id                     stop_name
# 1380771        2      Long Beach Blvd & 8th NE
# 1380944        4     Long Beach Blvd & 10th NE
# 1381023        5  Long Beach Blvd & Anaheim NE
# 1381024        6     Long Beach Blvd & 16th NE
# 1382337        8               PCH & Locust NE

# %%
sorted(long_beach_ridership["stop_id"].astype(int).unique())[:10]
# Out:
# [2, 4, 5, 6, 8, 9, 11, 12, 13, 14]

# %%
len(long_beach_ridership[["stop_id", "stop_name"]].drop_duplicates())
# Out:
# 1931

# %%
long_beach_gtfs = df_gtfs[df_gtfs["organization_name"] == "Long Beach Transit"]
long_beach_gtfs.head(3)
# Out:
#                       schedule_feed_key       date   organization_name  \
# 20396  28a47f8fac97a7e376de3b0312c9dc6c 2026-01-04  Long Beach Transit
# 20397  28a47f8fac97a7e376de3b0312c9dc6c 2026-01-04  Long Beach Transit
# 20398  28a47f8fac97a7e376de3b0312c9dc6c 2026-01-04  Long Beach Transit
#
#              service_name    gtfs_dataset_name gtfs_stop_id tts_stop_name  \
# 20396  Long Beach Transit  Long Beach Schedule         1271          None
# 20397  Long Beach Transit  Long Beach Schedule         2002          None
# 20398  Long Beach Transit  Long Beach Schedule         0502          None
#
#             gtfs_stop_name      stop_lat        stop_lon  \
# 20396  Carson & Worsham NW  33.832521000  -118.146003000
# 20397  2660 Del Amo Blvd S  33.846526000  -118.214765000
# 20398  Anaheim & Molino NW  33.782681000  -118.161403000
#
#                                                  website
# 20396  https://drive.google.com/uc?export=download&id...
# 20397  https://drive.google.com/uc?export=download&id...
# 20398  https://drive.google.com/uc?export=download&id...

# %%
long_beach_gtfs[["gtfs_stop_id", "gtfs_stop_name"]].drop_duplicates().sort_values(by="gtfs_stop_id").head()
# Out:
#       gtfs_stop_id                gtfs_stop_name
# 21611         0002      Long Beach Blvd & 8th NE
# 21155         0004     Long Beach Blvd & 10th NE
# 21834         0005  Long Beach Blvd & Anaheim NE
# 21563         0006     Long Beach Blvd & 16th NE
# 21556         0008               PCH & Locust NE

# %%
len(long_beach_gtfs[["gtfs_stop_id", "gtfs_stop_name"]].drop_duplicates())
# Out:
# 1893

# %%
sorted(long_beach_gtfs["gtfs_stop_id"].unique())[:10]
# Out:
# ['0002',
#  '0004',
#  '0005',
#  '0006',
#  '0008',
#  '0009',
#  '0011',
#  '0012',
#  '0013',
#  '0014']

# %%
# Out:
# Empty DataFrame
# Columns: [schedule_feed_key, date, organization_name, service_name, gtfs_dataset_name, gtfs_stop_id, tts_stop_name, gtfs_stop_name, stop_lat, stop_lon, website]
# Index: []

# %% [markdown]
# #### Golden Gata Park Shuttle

# %% [markdown]
# Map in stop id, lat and lon using stop name (special cases needs attention when joining)

# %%
ggp_gtfs = df_gtfs[df_gtfs["organization_name"] == "City and County of San Francisco"]
ggp_gtfs.head(3)
# Out:
#                       schedule_feed_key       date  \
# 11391  9bf417c6c0615f3f0bca7723c940a4f1 2026-01-04
# 11392  9bf417c6c0615f3f0bca7723c940a4f1 2026-01-04
# 11393  9bf417c6c0615f3f0bca7723c940a4f1 2026-01-04
#
#                       organization_name              service_name  \
# 11391  City and County of San Francisco  Golden Gate Park Shuttle
# 11392  City and County of San Francisco  Golden Gate Park Shuttle
# 11393  City and County of San Francisco  Golden Gate Park Shuttle
#
#                                     gtfs_dataset_name gtfs_stop_id  \
# 11391  Bay Area 511 Golden Gate Park Shuttle Schedule         7601
# 11392  Bay Area 511 Golden Gate Park Shuttle Schedule         7602
# 11393  Bay Area 511 Golden Gate Park Shuttle Schedule         7603
#
#       tts_stop_name         gtfs_stop_name      stop_lat        stop_lon  \
# 11391          None             Transverse  37.770534000  -122.479657000
# 11392          None        Blue Heron Lake  37.770840000  -122.476829000
# 11393          None  Rose Garden Westbound  37.771377000  -122.470697000
#
#                                                  website
# 11391  https://api.511.org/transit/datafeeds?operator...
# 11392  https://api.511.org/transit/datafeeds?operator...
# 11393  https://api.511.org/transit/datafeeds?operator...

# %%
ggp_ridership = df_ridership[df_ridership["organization_name"] == "City and County of San Francisco"]
ggp_ridership.head(3)
# Out:
#    Unnamed: 0         record_id        dataset_id  \
# 0           0  CEC173BF54FECCBD  189FC69D989010FD
# 1           1  1BF770A6DC9B06BC  189FC69D989010FD
# 2           2  19C42A2D3DD5337A  189FC69D989010FD
#
#                   organization_name              service_name route_id  \
# 0  City and County of San Francisco  Golden Gate Park Shuttle      NaN
# 1  City and County of San Francisco  Golden Gate Park Shuttle      NaN
# 2  City and County of San Francisco  Golden Gate Park Shuttle      NaN
#
#   route_name direction stop_id             stop_name  stop_lat  stop_lon  \
# 0        NaN       NaN    <NA>  Blue Heron Boathouse       NaN       NaN
# 1        NaN       NaN    <NA>  Blue Heron Boathouse       NaN       NaN
# 2        NaN       NaN    <NA>  Blue Heron Boathouse       NaN       NaN
#
#    avg_boardings  avg_alightings  avg_ridership day_type agg_basis  \
# 0            NaN             NaN           45.0  Weekday     daily
# 1            NaN             NaN           59.0  Weekday     daily
# 2            NaN             NaN           74.0  Weekday     daily
#
#    start_date    end_date gtfs_stop_id
# 0  2024-07-01  2024-07-01         <NA>
# 1  2024-07-02  2024-07-02         <NA>
# 2  2024-07-03  2024-07-03         <NA>

# %%
sorted(ggp_ridership["stop_name"].unique())
# Out:
# ['10th Ave/ De Young EB',
#  '10th Ave/ De Young WB',
#  '8th Ave EB',
#  '8th Ave WB',
#  'Academy of Sciences',
#  'Blue Heron Boathouse',
#  'Conservatory of Flowers EB',
#  'Conservatory of Flowers WB',
#  'De Young Museum',
#  'Haight/Stanyan',
#  'JFK Gateway EB',
#  'JFK Gateway WB',
#  'Music Concourse',
#  'Rose Garden - EB',
#  'Rose Garden WB',
#  'Tennis Center/ Dalia Dell EB',
#  'Tennis Center/ Dalia Dell WB',
#  'Transverse']

# %%
ggp_gtfs[["gtfs_stop_id", "gtfs_stop_name", "stop_lat", "stop_lon"]].drop_duplicates().sort_values(by="gtfs_stop_id")
# Out:
#       gtfs_stop_id                           gtfs_stop_name      stop_lat  \
# 11391         7601                               Transverse  37.770534000
# 11392         7602                          Blue Heron Lake  37.770840000
# 11393         7603                    Rose Garden Westbound  37.771377000
# 11394         7604                    Rose Garden Eastbound  37.771331000
# 11395         7605                    de Young / Tea Garden  37.770479000
# 11396         7606                Music Concourse/Bandshell  37.769431000
# 11397         7607  10th Avenue / Music Concourse Eastbound  37.772442000
# 11398         7608  10th Avenue / Music Concourse Westbound  37.772584000
# 11399         7609                              Cal Academy  37.770716000
# 11400         7610                                  8th Ave  37.772490000
# 11401         7611                                  8th Ave  37.772720000
# 11402         7612        Conservatory of Flowers Eastbound  37.771779000
# 11403         7613        Conservatory of Flowers Westbound  37.771792000
# 11404         7614    Tennis Center / Dahlia Dell Westbound  37.771382000
# 11405         7615    Tennis Center / Dahlia Dell Eastbound  37.771230000
# 11406         7618                         Haight / Stanyan  37.769270000
# 11407         7619                           JFK Gateway EB  37.770950000
# 11408         7620                           JFK Gateway WB  37.770940000
#
#              stop_lon
# 11391  -122.479657000
# 11392  -122.476829000
# 11393  -122.470697000
# 11394  -122.470492000
# 11395  -122.468920000
# 11396  -122.468734000
# 11397  -122.468200000
# 11398  -122.468183000
# 11399  -122.466159000
# 11400  -122.465720000
# 11401  -122.465660000
# 11402  -122.462264000
# 11403  -122.461825000
# 11404  -122.459239000
# 11405  -122.458979000
# 11406  -122.452950000
# 11407  -122.456650000
# 11408  -122.455990000

# %% [markdown]
# #### BART

# %%
bart_ridership = df_ridership[df_ridership["organization_name"] == "San Francisco Bay Area Rapid Transit District"]
bart_ridership.head(3)
# Out:
#          Unnamed: 0         record_id        dataset_id  \
# 1350809     1350809  88FE6E83739E40E9  011CF30F49575609
# 1350810     1350810  FD3B1545969AD5A1  011CF30F49575609
# 1350811     1350811  F16515EA15C66BE3  011CF30F49575609
#
#                                      organization_name  \
# 1350809  San Francisco Bay Area Rapid Transit District
# 1350810  San Francisco Bay Area Rapid Transit District
# 1350811  San Francisco Bay Area Rapid Transit District
#
#                    service_name route_id route_name direction stop_id  \
# 1350809  Bay Area Rapid Transit      NaN        NaN       NaN    <NA>
# 1350810  Bay Area Rapid Transit      NaN        NaN       NaN    <NA>
# 1350811  Bay Area Rapid Transit      NaN        NaN       NaN    <NA>
#
#                                  stop_name  ... stop_lon avg_boardings  \
# 1350809  12th Street / Oakland City Center  ...      NaN        5946.0
# 1350810                16th Street Mission  ...      NaN        6259.0
# 1350811              19th Street / Oakland  ...      NaN        5573.0
#
#          avg_alightings  avg_ridership  day_type agg_basis  start_date  \
# 1350809          5918.0            NaN   Weekday     daily  2024-10-01
# 1350810          6015.0            NaN   Weekday     daily  2024-10-01
# 1350811          5432.0            NaN   Weekday     daily  2024-10-01
#
#            end_date gtfs_stop_id stop_loc_source
# 1350809  2024-10-01         <NA>             NaN
# 1350810  2024-10-01         <NA>             NaN
# 1350811  2024-10-01         <NA>             NaN
#
# [3 rows x 21 columns]

# %%
bart_gtfs = df_gtfs[df_gtfs["organization_name"] == "San Francisco Bay Area Rapid Transit District"]
bart_gtfs.head(3)
# Out:
# Empty DataFrame
# Columns: [schedule_feed_key, date, organization_name, service_name, gtfs_dataset_name, gtfs_stop_id, tts_stop_name, gtfs_stop_name, stop_lat, stop_lon, website]
# Index: []

# %%
sorted(bart_ridership["stop_name"].unique())
# Out:
# ['12th Street / Oakland City Center',
#  '16th Street Mission',
#  '19th Street / Oakland',
#  '24th Street Mission',
#  'Antioch',
#  'Ashby',
#  'Balboa Park',
#  'Bayfair',
#  'Berryessa',
#  'Castro Valley',
#  'Civic Center / UN Plaza',
#  'Coliseum',
#  'Colma',
#  'Concord',
#  'Daly City',
#  'Downtown Berkeley',
#  'Dublin / Pleasanton',
#  'El Cerrito Del Norte',
#  'El Cerrito Plaza',
#  'Embarcadero',
#  'Fremont',
#  'Fruitvale',
#  'Glen Park',
#  'Hayward',
#  'Lafayette',
#  'Lake Merritt',
#  'MacArthur',
#  'Millbrae',
#  'Milpitas',
#  'Montgomery Street',
#  'North Berkeley',
#  'North Concord / Martinez',
#  'Oakland International Airport (OAK)',
#  'Orinda',
#  'Pittsburg / Bay Point',
#  'Pittsburg Center',
#  'Pleasant Hill / Contra Costa Centre',
#  'Powell Street',
#  'Richmond',
#  'Rockridge',
#  'San Bruno',
#  'San Francisco International Airport (SFO)',
#  'San Leandro',
#  'South Hayward',
#  'South San Francisco',
#  'Union City',
#  'Walnut Creek',
#  'Warm Springs / South Fremont',
#  'West Dublin / Pleasanton',
#  'West Oakland']

# %% [markdown]
# #### OmniTrans

# %% [markdown]
# Map in stop lat and lon using stop name.

# %%
omni_ridership = df_ridership[df_ridership["organization_name"] == "OmniTrans"]
omni_ridership.head(3)
# Out:
#          Unnamed: 0         record_id        dataset_id organization_name  \
# 1389443     1389443  D6F2B598A671C4EB  40F5F343F0BD5850         OmniTrans
# 1389444     1389444  8C772D5F9586B138  40F5F343F0BD5850         OmniTrans
# 1389445     1389445  F03287536AC9CDC9  40F5F343F0BD5850         OmniTrans
#
#         service_name route_id route_name direction stop_id   stop_name  \
# 1389443    OmniTrans        1        NaN       NaN    <NA>  2ND @ F ST
# 1389444    OmniTrans        1        NaN       NaN    <NA>  2ND @ G ST
# 1389445    OmniTrans        1        NaN       NaN    <NA>  2ND @ J ST
#
#          stop_lat  stop_lon  avg_boardings  avg_alightings  avg_ridership  \
# 1389443       NaN       NaN       2.572603        0.619178            NaN
# 1389444       NaN       NaN       1.410959        7.701370            NaN
# 1389445       NaN       NaN       2.753425        1.254795            NaN
#
#         day_type    agg_basis  start_date    end_date gtfs_stop_id
# 1389443      all  fiscal year  2023-07-01  2024-06-30         <NA>
# 1389444      all  fiscal year  2023-07-01  2024-06-30         <NA>
# 1389445      all  fiscal year  2023-07-01  2024-06-30         <NA>

# %%
omni_gtfs = df_gtfs[df_gtfs["organization_name"] == "OmniTrans"]
omni_gtfs.head(3)
# Out:
#                      schedule_feed_key       date organization_name  \
# 4257  c23c8c76fe957c181b29448b1fdb746a 2026-01-04         OmniTrans
# 4258  c23c8c76fe957c181b29448b1fdb746a 2026-01-04         OmniTrans
# 4259  c23c8c76fe957c181b29448b1fdb746a 2026-01-04         OmniTrans
#
#      service_name   gtfs_dataset_name gtfs_stop_id tts_stop_name  \
# 4257    OmniTrans  OmniTrans Schedule         8515          None
# 4258    OmniTrans  OmniTrans Schedule         8312          None
# 4259    OmniTrans  OmniTrans Schedule         5699          None
#
#                       gtfs_stop_name      stop_lat        stop_lon  \
# 4257               G Street @ Valley  34.097389000  -117.298576000
# 4258  sbX - Hospitality @ Hunts Lane  34.065830000  -117.287740000
# 4259             Baseline @ McKinley  34.121195000  -117.237742000
#
#                                                 website
# 4257  https://www.omnitrans.org/google/google_transi...
# 4258  https://www.omnitrans.org/google/google_transi...
# 4259  https://www.omnitrans.org/google/google_transi...

# %%
len(omni_ridership[['stop_name']].drop_duplicates())
# Out:
# 1427

# %%
# sorted(omni_ridership["stop_name"].unique())

# %%
# sorted(omni_gtfs["gtfs_stop_name"].unique())

# %%
# sorted(set(omni_ridership["stop_name"].unique()) - set(omni_gtfs["gtfs_stop_name"].unique()))

# %%
sorted(omni_ridership["stop_name"].unique())[:10]
# Out:
# ['11th @ M',
#  '11th @ N',
#  '19TH @ AMETHYST',
#  '19TH @ ARCHIBALD',
#  '19TH @ BERYL',
#  '19TH @ HAVEN',
#  '19TH @ HELLMAN',
#  '19TH @ HERMOSA',
#  '19TH @ MAYBERRY',
#  '19TH @ RAMONA']

# %%
sorted(omni_gtfs["gtfs_stop_name"].unique())[:20]
# Out:
# []

# %% [markdown]
# #### Caltrain

# %%
caltrain_ridership = df_ridership[df_ridership["organization_name"] == "Peninsula Corridor Joint Powers Board"]
caltrain_ridership.head(3)
# Out:
#          Unnamed: 0         record_id        dataset_id  \
# 1880211     1880211  4E9B97EDFBF3B54E  D3642CDF7FD75B27
# 1880212     1880212  0DF5F5B7E483D20E  D3642CDF7FD75B27
# 1880213     1880213  D248BED7E8F69100  D3642CDF7FD75B27
#
#                              organization_name service_name route_id  \
# 1880211  Peninsula Corridor Joint Powers Board     Caltrain      NaN
# 1880212  Peninsula Corridor Joint Powers Board     Caltrain      NaN
# 1880213  Peninsula Corridor Joint Powers Board     Caltrain      NaN
#
#         route_name direction stop_id    stop_name  ... stop_lon avg_boardings  \
# 1880211        NaN       NaN    <NA>  22nd Street  ...      NaN           NaN
# 1880212        NaN       NaN    <NA>     Bayshore  ...      NaN           NaN
# 1880213        NaN       NaN    <NA>      Belmont  ...      NaN           NaN
#
#          avg_alightings  avg_ridership  day_type agg_basis  start_date  \
# 1880211             NaN    1525.276001   Weekday   monthly  2025-07-01
# 1880212             NaN     241.102249   Weekday   monthly  2025-07-01
# 1880213             NaN     755.198175   Weekday   monthly  2025-07-01
#
#            end_date gtfs_stop_id stop_loc_source
# 1880211  2025-07-31         <NA>             NaN
# 1880212  2025-07-31         <NA>             NaN
# 1880213  2025-07-31         <NA>             NaN
#
# [3 rows x 21 columns]

# %%
sorted(caltrain_ridership["stop_name"].unique())
# Out:
# ['22nd Street',
#  'Bayshore',
#  'Belmont',
#  'Blossom Hill',
#  'Broadway',
#  'Burlingame',
#  'California Ave',
#  'Capitol',
#  'College Park',
#  'Gilroy',
#  'Hayward Park',
#  'Hillsdale',
#  'Lawrence',
#  'Menlo Park',
#  'Millbrae',
#  'Morgan Hill',
#  'Mountain View',
#  'Palo Alto',
#  'Redwood City',
#  'San Antonio',
#  'San Bruno',
#  'San Carlos',
#  'San Francisco',
#  'San Jose Diridon',
#  'San Martin',
#  'San Mateo',
#  'Santa Clara',
#  'South San Francisco',
#  'Sunnyvale',
#  'Tamien']

# %%
caltrain_gtfs = df_gtfs[df_gtfs["organization_name"] == "Peninsula Corridor Joint Powers Board"]
caltrain_gtfs.head(3)
# Out:
#                       schedule_feed_key       date  \
# 17273  35c020db5e570651ea9048db2ae7d366 2025-12-31
# 17274  35c020db5e570651ea9048db2ae7d366 2025-12-31
# 17275  35c020db5e570651ea9048db2ae7d366 2025-12-31
#
#                            organization_name service_name  gtfs_dataset_name  \
# 17273  Peninsula Corridor Joint Powers Board     Caltrain  Caltrain Schedule
# 17274  Peninsula Corridor Joint Powers Board     Caltrain  Caltrain Schedule
# 17275  Peninsula Corridor Joint Powers Board     Caltrain  Caltrain Schedule
#
#         gtfs_stop_id  tts_stop_name                  gtfs_stop_name  \
# 17273      palo_alto      palo alto               Palo Alto Station
# 17274  san_francisco  san francisco  San Francisco Caltrain Station
# 17275       broadway       broadway                Broadway Station
#
#            stop_lat        stop_lon  \
# 17273  37.443220000  -122.164290000
# 17274  37.776404000  -122.394911000
# 17275  37.587260000  -122.362000000
#
#                                                  website
# 17273  https://data.trilliumtransit.com/gtfs/caltrain...
# 17274  https://data.trilliumtransit.com/gtfs/caltrain...
# 17275  https://data.trilliumtransit.com/gtfs/caltrain...

# %%
caltrain_gtfs[caltrain_gtfs["gtfs_stop_name"].str.contains("22nd Street")]
# Out:
#                       schedule_feed_key       date  \
# 17309  35c020db5e570651ea9048db2ae7d366 2025-12-31
# 17310  35c020db5e570651ea9048db2ae7d366 2025-12-31
# 17342  35c020db5e570651ea9048db2ae7d366 2025-12-31
# 17343  35c020db5e570651ea9048db2ae7d366 2025-12-31
# 17345  35c020db5e570651ea9048db2ae7d366 2025-12-31
# 31965  f0273bbe3a09a067fbee1a35eb5708a2 2025-12-31
# 31966  f0273bbe3a09a067fbee1a35eb5708a2 2025-12-31
# 32017  f0273bbe3a09a067fbee1a35eb5708a2 2025-12-31
# 32032  f0273bbe3a09a067fbee1a35eb5708a2 2025-12-31
# 32033  f0273bbe3a09a067fbee1a35eb5708a2 2025-12-31
#
#                            organization_name service_name  \
# 17309  Peninsula Corridor Joint Powers Board     Caltrain
# 17310  Peninsula Corridor Joint Powers Board     Caltrain
# 17342  Peninsula Corridor Joint Powers Board     Caltrain
# 17343  Peninsula Corridor Joint Powers Board     Caltrain
# 17345  Peninsula Corridor Joint Powers Board     Caltrain
# 31965  Peninsula Corridor Joint Powers Board     Caltrain
# 31966  Peninsula Corridor Joint Powers Board     Caltrain
# 32017  Peninsula Corridor Joint Powers Board     Caltrain
# 32032  Peninsula Corridor Joint Powers Board     Caltrain
# 32033  Peninsula Corridor Joint Powers Board     Caltrain
#
#                     gtfs_dataset_name gtfs_stop_id         tts_stop_name  \
# 17309               Caltrain Schedule  22nd_street  twenty second street
# 17310               Caltrain Schedule  22nd_street  twenty second street
# 17342               Caltrain Schedule        70022                  None
# 17343               Caltrain Schedule        70022                  None
# 17345               Caltrain Schedule        70021                  None
# 31965  Bay Area 511 Caltrain Schedule  22nd_street                  None
# 31966  Bay Area 511 Caltrain Schedule  22nd_street                  None
# 32017  Bay Area 511 Caltrain Schedule        70021                  None
# 32032  Bay Area 511 Caltrain Schedule        70022                  None
# 32033  Bay Area 511 Caltrain Schedule        70022                  None
#
#                                 gtfs_stop_name      stop_lat        stop_lon  \
# 17309                      22nd Street Station  37.756972000  -122.392492000
# 17310                      22nd Street Station  37.756972000  -122.392492000
# 17342          22nd Street Caltrain Southbound  37.757583000  -122.392404000
# 17343          22nd Street Caltrain Southbound  37.757583000  -122.392404000
# 17345          22nd Street Caltrain Northbound  37.757599000  -122.391880000
# 31965                              22nd Street  37.756972000  -122.392492000
# 31966                              22nd Street  37.756972000  -122.392492000
# 32017  22nd Street Caltrain Station Northbound  37.757599000  -122.391880000
# 32032  22nd Street Caltrain Station Southbound  37.757583000  -122.392404000
# 32033  22nd Street Caltrain Station Southbound  37.757583000  -122.392404000
#
#                                                  website
# 17309  https://data.trilliumtransit.com/gtfs/caltrain...
# 17310  https://data.trilliumtransit.com/gtfs/caltrain...
# 17342  https://data.trilliumtransit.com/gtfs/caltrain...
# 17343  https://data.trilliumtransit.com/gtfs/caltrain...
# 17345  https://data.trilliumtransit.com/gtfs/caltrain...
# 31965  https://api.511.org/transit/datafeeds?operator...
# 31966  https://api.511.org/transit/datafeeds?operator...
# 32017  https://api.511.org/transit/datafeeds?operator...
# 32032  https://api.511.org/transit/datafeeds?operator...
# 32033  https://api.511.org/transit/datafeeds?operator...

# %%
caltrain_gtfs[["gtfs_dataset_name", "gtfs_stop_name"]].drop_duplicates().sort_values(by="gtfs_stop_name").head(10)
# Out:
#                     gtfs_dataset_name                           gtfs_stop_name
# 31965  Bay Area 511 Caltrain Schedule                              22nd Street
# 17345               Caltrain Schedule          22nd Street Caltrain Northbound
# 17342               Caltrain Schedule          22nd Street Caltrain Southbound
# 32017  Bay Area 511 Caltrain Schedule  22nd Street Caltrain Station Northbound
# 32032  Bay Area 511 Caltrain Schedule  22nd Street Caltrain Station Southbound
# 17309               Caltrain Schedule                      22nd Street Station
# 32045  Bay Area 511 Caltrain Schedule                                 Bayshore
# 17338               Caltrain Schedule             Bayshore Caltrain Northbound
# 17346               Caltrain Schedule             Bayshore Caltrain Southbound
# 31957  Bay Area 511 Caltrain Schedule     Bayshore Caltrain Station Northbound

# %% [markdown]
# #### Santa Cruz Metro

# %%
scm_ridership = df_ridership[df_ridership["organization_name"] == "Santa Cruz Metropolitan Transit District"].sort_values(by="stop_name")
scm_ridership_stop = scm_ridership[["stop_id", "stop_name"]].drop_duplicates().sort_values(by="stop_id")
scm_ridership_stop.head(10)
# Out:
#       stop_id                                    stop_name
# 68710    1001                    Airport Blvd + Airport Rd
# 68707    1002                       Airport Blvd (Airport)
# 68712    1005                       Airport Blvd + Holm Rd
# 68708    1006                Airport Blvd (Freedom Centre)
# 68718    1015  Amesti Rd + Green Valley Rd (Amesti School)
# 68719    1020                         Amesti Rd + Mann Ave
# 68716    1026                     Amesti Rd + Bollinger Pl
# 68777    1034                   Bowker Rd + Buena Vista Dr
# 68778    1035                     Bowker Rd + Calabasas Rd
# 68798    1044             Browns Valley Rd + Corralitos Rd

# %%
scm_ridership[scm_ridership["stop_name"].str.startswith("Barack Obama Blvd")]
# Out:
#        Unnamed: 0         record_id        dataset_id  \
# 68727       68727  8B171A2321D3AE1B  581003114DDAFDBE
# 68728       68728  C66302F57E8C59B3  581003114DDAFDBE
# 68730       68730  B8CE486DA200B870  581003114DDAFDBE
# 68729       68729  DCFC1E5892DDFE81  581003114DDAFDBE
#
#                               organization_name      service_name route_id  \
# 68727  Santa Cruz Metropolitan Transit District  Santa Cruz METRO      NaN
# 68728  Santa Cruz Metropolitan Transit District  Santa Cruz METRO      NaN
# 68730  Santa Cruz Metropolitan Transit District  Santa Cruz METRO      NaN
# 68729  Santa Cruz Metropolitan Transit District  Santa Cruz METRO      NaN
#
#       route_name direction stop_id                         stop_name  \
# 68727        NaN       NaN     915      Barack Obama Blvd + Park Ave
# 68728        NaN       NaN     923      Barack Obama Blvd + Park Ave
# 68730        NaN       NaN     902  Barack Obama Blvd + W San Carlos
# 68729        NaN       NaN     901  Barack Obama Blvd + W San Carlos
#
#        stop_lat  stop_lon  daily_boardings  daily_alightings  \
# 68727       NaN       NaN         1.621918          0.164384
# 68728       NaN       NaN         0.049315          1.613699
# 68730       NaN       NaN        12.098630          0.624658
# 68729       NaN       NaN         0.720548         16.610959
#
#        daily_total_ridership day_type daily_ridership_basis  start_date  \
# 68727                    NaN      all  calculated_avg_daily  2024-07-01
# 68728                    NaN      all  calculated_avg_daily  2024-07-01
# 68730                    NaN      all  calculated_avg_daily  2024-07-01
# 68729                    NaN      all  calculated_avg_daily  2024-07-01
#
#          end_date gtfs_stop_id
# 68727  2025-06-30         <NA>
# 68728  2025-06-30         <NA>
# 68730  2025-06-30         <NA>
# 68729  2025-06-30         <NA>

# %%
len(scm_ridership_stop[["stop_id", "stop_name"]].drop_duplicates())
# Out:
# 778

# %%
scm_gtfs = df_gtfs[df_gtfs["organization_name"] == "Santa Cruz Metropolitan Transit District"].sort_values(by="gtfs_stop_name")
scm_gtfs_stop = scm_gtfs[["gtfs_stop_id", "stop_code", "gtfs_stop_name"]].drop_duplicates().sort_values(by="stop_code")
scm_gtfs_stop.head(10)
# Out:
#      gtfs_stop_id stop_code                    gtfs_stop_name
# 4504          864      0901  Barack Obama Blvd & W San Carlos
# 4505          865      0902  Barack Obama Blvd & W San Carlos
# 4506          866      0904  Diridon Station (Caltrain Depot)
# 4507          867      0906        W Santa Clara & Delmas Ave
# 4508          868      0908      W Santa Clara & Almaden Blvd
# 4509          869      0910             E Santa Clara & S 1st
# 4510          870      0912          W Santa Clara & S Market
# 4511          871      0913        W Santa Clara & Delmas Ave
# 4512          872      0914            E San Fernando & S 7th
# 4513          873      0915      Barack Obama Blvd & Park Ave

# %%
scm_gtfs_stop[scm_gtfs_stop["gtfs_stop_name"].str.startswith("Barack Obama")]
# Out:
#      gtfs_stop_id stop_code                    gtfs_stop_name
# 4504          864      0901  Barack Obama Blvd & W San Carlos
# 4505          865      0902  Barack Obama Blvd & W San Carlos
# 4513          873      0915      Barack Obama Blvd & Park Ave
# 4516          876      0923      Barack Obama Blvd & Park Ave

# %%
len(scm_gtfs_stop)
# Out:
# 791

# %% [markdown]
# #### SDMTS

# %%
sdmts_ridership = df_ridership[df_ridership["organization_name"] == "San Diego Metropolitan Transit System"]
sdmts_ridership.head(3)
# Out:
#          Unnamed: 0         record_id        dataset_id  \
# 1314960     1314960  D29BC2478CE4EF31  923349C0D2AC9D75
# 1314961     1314961  D892874972D4A7CC  923349C0D2AC9D75
# 1314962     1314962  BF8E5C0EEA4C825C  923349C0D2AC9D75
#
#                              organization_name  \
# 1314960  San Diego Metropolitan Transit System
# 1314961  San Diego Metropolitan Transit System
# 1314962  San Diego Metropolitan Transit System
#
#                                   service_name route_id  \
# 1314960  San Diego Metropolitan Transit System        1
# 1314961  San Diego Metropolitan Transit System        1
# 1314962  San Diego Metropolitan Transit System        1
#
#                        route_name direction stop_id  \
# 1314960  1:Fashion Valley-La Mesa      East   10106
# 1314961  1:Fashion Valley-La Mesa      East   10111
# 1314962  1:Fashion Valley-La Mesa      East   10114
#
#                            stop_name  stop_lat  stop_lon  avg_boardings  \
# 1314960      University Av & 10th Av       NaN       NaN      26.228026
# 1314961   University Av & Vermont St       NaN       NaN      59.583915
# 1314962  University Av & Richmond St       NaN       NaN      14.963778
#
#          avg_alightings  avg_ridership day_type       agg_basis  start_date  \
# 1314960       15.629832            NaN  Weekday  service period  2024-09-01
# 1314961       17.940893            NaN  Weekday  service period  2024-09-01
# 1314962       14.173884            NaN  Weekday  service period  2024-09-01
#
#            end_date gtfs_stop_id
# 1314960  2025-01-25         <NA>
# 1314961  2025-01-25         <NA>
# 1314962  2025-01-25         <NA>

# %%
sdmts_ridership[["stop_id", "stop_name"]].drop_duplicates().sort_values(by="stop_id").head()
# Out:
#         stop_id                      stop_name
# 1317183   10001     Cabrillo National Monument
# 1316610   10003           Pearl St & Draper Av
# 1316611   10004              Pearl St & Fay Av
# 1316612   10006  Torrey Pines Rd & Exchange Pl
# 1316613   10007  Torrey Pines Rd & Princess St

# %%
len(sdmts_ridership[["stop_id", "stop_name"]].drop_duplicates())
# Out:
# 4172

# %%
sdmts_gtfs = df_gtfs[df_gtfs["organization_name"] == "San Diego Metropolitan Transit System"]
sdmts_gtfs.head(3)
# Out:
#                       schedule_feed_key       date  \
# 23892  6ec100ffba38b0007881f35ed4240e72 2025-12-31
# 23893  6ec100ffba38b0007881f35ed4240e72 2025-12-31
# 23894  6ec100ffba38b0007881f35ed4240e72 2025-12-31
#
#                            organization_name  \
# 23892  San Diego Metropolitan Transit System
# 23893  San Diego Metropolitan Transit System
# 23894  San Diego Metropolitan Transit System
#
#                                 service_name   gtfs_dataset_name gtfs_stop_id  \
# 23892  San Diego Metropolitan Transit System  San Diego Schedule        99302
# 23893  San Diego Metropolitan Transit System  San Diego Schedule        12925
# 23894  San Diego Metropolitan Transit System  San Diego Schedule        12156
#
#       tts_stop_name                    gtfs_stop_name      stop_lat  \
# 23892          None                     4th St & U Av  32.685362700
# 23893          None  Bernardo Center Dr & Fairhope Rd  33.031911020
# 23894          None    Carmel Mountain Rd & Gerana St  32.973029580
#
#              stop_lon                                            website
# 23892  -117.087081160  https://www.sdmts.com/google_transit_files/goo...
# 23893  -117.074989740  https://www.sdmts.com/google_transit_files/goo...
# 23894  -117.093029690  https://www.sdmts.com/google_transit_files/goo...

# %%
sdmts_gtfs[["gtfs_stop_id", "gtfs_stop_name"]].drop_duplicates().sort_values(by="gtfs_stop_id").head()
# Out:
#       gtfs_stop_id                 gtfs_stop_name
# 27702        10001     Cabrillo National Monument
# 28203        10003           Pearl St & Draper Av
# 26403        10004              Pearl St & Fay Av
# 27534        10006  Torrey Pines Rd & Exchange Pl
# 27119        10007  Torrey Pines Rd & Princess St

# %% [markdown]
# #### SBMTD

# %%
sbmtd_ridership = df_ridership[df_ridership["organization_name"] == "Santa Barbara Metropolitan Transit District"]
sbmtd_ridership.head(3)
# Out:
#          Unnamed: 0         record_id        dataset_id  \
# 1394275     1394275  093FFEEAE78D8A1F  165BA8D319143274
# 1394276     1394276  51283605FE66907F  165BA8D319143274
# 1394277     1394277  F35477031A36354B  165BA8D319143274
#
#                                    organization_name  \
# 1394275  Santa Barbara Metropolitan Transit District
# 1394276  Santa Barbara Metropolitan Transit District
# 1394277  Santa Barbara Metropolitan Transit District
#
#                                         service_name route_id route_name  \
# 1394275  Santa Barbara Metropolitan Transit District      NaN        NaN
# 1394276  Santa Barbara Metropolitan Transit District      NaN        NaN
# 1394277  Santa Barbara Metropolitan Transit District      NaN        NaN
#
#         direction stop_id              stop_name  stop_lat  stop_lon  \
# 1394275       NaN       1    Modoc & Portesuello       NaN       NaN
# 1394276       NaN       2     Milpas & Montecito       NaN       NaN
# 1394277       NaN       3  Via Real & Santa Ynez       NaN       NaN
#
#          avg_boardings  avg_alightings  avg_ridership day_type agg_basis  \
# 1394275      52.166667       26.900000      79.100000      all   monthly
# 1394276     114.500000       49.633333     164.133333      all   monthly
# 1394277      24.900000        6.400000      31.300000      all   monthly
#
#          start_date    end_date gtfs_stop_id
# 1394275  2024-11-01  2024-11-30         <NA>
# 1394276  2024-11-01  2024-11-30         <NA>
# 1394277  2024-11-01  2024-11-30         <NA>

# %%
sbmtd_ridership[["stop_id", "stop_name"]].drop_duplicates().sort_values(by="stop_id").head()
# Out:
#         stop_id                stop_name
# 1394275       1      Modoc & Portesuello
# 1394283      10  Anapamu & Santa Barbara
# 1394359     100        San Andres & Sola
# 1394360     101     San Andres & Anapamu
# 1394361     102    Carrillo & San Andres

# %%
len(sbmtd_ridership[["stop_id", "stop_name"]].drop_duplicates())
# Out:
# 632

# %%
sbmtd_gtfs = df_gtfs[df_gtfs["organization_name"] == "Santa Barbara Metropolitan Transit District"]
sbmtd_gtfs.head(3)
# Out:
#                       schedule_feed_key       date  \
# 22353  df1ffaa43a5e7b3ce2f7bebd97d14662 2026-01-04
# 22354  df1ffaa43a5e7b3ce2f7bebd97d14662 2026-01-04
# 22355  df1ffaa43a5e7b3ce2f7bebd97d14662 2026-01-04
#
#                                  organization_name  \
# 22353  Santa Barbara Metropolitan Transit District
# 22354  Santa Barbara Metropolitan Transit District
# 22355  Santa Barbara Metropolitan Transit District
#
#                                       service_name gtfs_dataset_name  \
# 22353  Santa Barbara Metropolitan Transit District    SBMTD Schedule
# 22354  Santa Barbara Metropolitan Transit District    SBMTD Schedule
# 22355  Santa Barbara Metropolitan Transit District    SBMTD Schedule
#
#       gtfs_stop_id tts_stop_name           gtfs_stop_name      stop_lat  \
# 22353            1          None      Modoc & Portesuello  34.424858000
# 22354           10          None  Anapamu & Santa Barbara  34.425301000
# 22355          100          None        San Andres & Sola  34.417937000
#
#              stop_lon                                    website
# 22353  -119.726070000  https://sbmtd.gov/google_transit/feed.zip
# 22354  -119.702300000  https://sbmtd.gov/google_transit/feed.zip
# 22355  -119.714983000  https://sbmtd.gov/google_transit/feed.zip

# %%
sbmtd_gtfs[["gtfs_stop_id", "gtfs_stop_name"]].drop_duplicates().sort_values(by="gtfs_stop_id").head()
# Out:
#       gtfs_stop_id           gtfs_stop_name
# 22353            1      Modoc & Portesuello
# 22354           10  Anapamu & Santa Barbara
# 22355          100        San Andres & Sola
# 22356          101     San Andres & Anapamu
# 22357          102    Carrillo & San Andres

# %%
sbmtd_gtfs[sbmtd_gtfs["gtfs_stop_name"].str.contains("Cabrillo & ")]
# Out:
#                       schedule_feed_key       date  \
# 22474  df1ffaa43a5e7b3ce2f7bebd97d14662 2026-01-04
# 22625  df1ffaa43a5e7b3ce2f7bebd97d14662 2026-01-04
# 22627  df1ffaa43a5e7b3ce2f7bebd97d14662 2026-01-04
# 22676  df1ffaa43a5e7b3ce2f7bebd97d14662 2026-01-04
# 22678  df1ffaa43a5e7b3ce2f7bebd97d14662 2026-01-04
#
#                                  organization_name  \
# 22474  Santa Barbara Metropolitan Transit District
# 22625  Santa Barbara Metropolitan Transit District
# 22627  Santa Barbara Metropolitan Transit District
# 22676  Santa Barbara Metropolitan Transit District
# 22678  Santa Barbara Metropolitan Transit District
#
#                                       service_name gtfs_dataset_name  \
# 22474  Santa Barbara Metropolitan Transit District    SBMTD Schedule
# 22625  Santa Barbara Metropolitan Transit District    SBMTD Schedule
# 22627  Santa Barbara Metropolitan Transit District    SBMTD Schedule
# 22676  Santa Barbara Metropolitan Transit District    SBMTD Schedule
# 22678  Santa Barbara Metropolitan Transit District    SBMTD Schedule
#
#       gtfs_stop_id tts_stop_name        gtfs_stop_name      stop_lat  \
# 22474          211          None  Cabrillo & Los Patos  34.421923000
# 22625          367          None     Cabrillo & Milpas  34.416883000
# 22627          370          None      Cabrillo & Ninos  34.417478000
# 22676          445          None     Cabrillo & Milpas  34.416818000
# 22678          447          None      Cabrillo & Ninos  34.417197000
#
#              stop_lon                                    website
# 22474  -119.656070000  https://sbmtd.gov/google_transit/feed.zip
# 22625  -119.672110000  https://sbmtd.gov/google_transit/feed.zip
# 22627  -119.668100000  https://sbmtd.gov/google_transit/feed.zip
# 22676  -119.671490000  https://sbmtd.gov/google_transit/feed.zip
# 22678  -119.669602000  https://sbmtd.gov/google_transit/feed.zip

# %% [markdown]
# #### OCTA

# %%
octa_ridership = df_ridership[df_ridership["organization_name"] == "Orange County Transportation Authority"]
octa_ridership["stop_id"] = octa_ridership["stop_id"].astype(int)
octa_ridership.head(3)
# Out:
#          Unnamed: 0         record_id        dataset_id  \
# 1874437     1874437  0A7CC90CD4C78239  26406E10C753AC29
# 1874438     1874438  C5941215B3224CF9  26406E10C753AC29
# 1874439     1874439  BFFF2EA254258231  26406E10C753AC29
#
#                               organization_name  \
# 1874437  Orange County Transportation Authority
# 1874438  Orange County Transportation Authority
# 1874439  Orange County Transportation Authority
#
#                                    service_name route_id  \
# 1874437  Orange County Transportation Authority      1.0
# 1874438  Orange County Transportation Authority      1.0
# 1874439  Orange County Transportation Authority      1.0
#
#                           route_name direction  stop_id  \
# 1874437  1-Long Beach - San Clemente         N     1501
# 1874438  1-Long Beach - San Clemente         N     1503
# 1874439  1-Long Beach - San Clemente         N     1506
#
#                                 stop_name  ... stop_lon avg_boardings  \
# 1874437     1501-PACIFIC COAST-DEL OBISPO  ...      NaN          36.0
# 1874438        1503-PACIFIC COAST-ALCAZAR  ...      NaN           3.0
# 1874439  1506-PACIFIC COAST-AMBER LANTERN  ...      NaN           6.0
#
#          avg_alightings  avg_ridership  day_type agg_basis  start_date  \
# 1874437            30.0            NaN   weekday     daily  2025-02-04
# 1874438             3.0            NaN   weekday     daily  2025-02-04
# 1874439             7.0            NaN   weekday     daily  2025-02-04
#
#            end_date gtfs_stop_id stop_loc_source
# 1874437  2025-02-04         <NA>             NaN
# 1874438  2025-02-04         <NA>             NaN
# 1874439  2025-02-04         <NA>             NaN
#
# [3 rows x 21 columns]

# %%
octa_ridership[["stop_id", "stop_name"]].drop_duplicates().sort_values(by="stop_id").head()
# Out:
#          stop_id            stop_name
# 1877204        2  2-HASTER-ORANGEWOOD
# 1877208        3   3-HASTER-WAKEFIELD
# 1877209        4     4-HASTER-KATELLA
# 1877223        5    5-ANAHEIM-KATELLA
# 1877237        6   6-ANAHEIM-CERRITOS

# %%
octa_gtfs = df_gtfs[df_gtfs["organization_name"] == "Orange County Transportation Authority"]
octa_gtfs.head(3)
# Out:
#                       schedule_feed_key       date  \
# 17381  0162e91a887ff92d5f82df29fddf98cc 2025-12-31
# 17382  0162e91a887ff92d5f82df29fddf98cc 2025-12-31
# 17383  0162e91a887ff92d5f82df29fddf98cc 2025-12-31
#
#                             organization_name  \
# 17381  Orange County Transportation Authority
# 17382  Orange County Transportation Authority
# 17383  Orange County Transportation Authority
#
#                                  service_name gtfs_dataset_name gtfs_stop_id  \
# 17381  Orange County Transportation Authority     OCTA Schedule         4123
# 17382  Orange County Transportation Authority     OCTA Schedule         4160
# 17383  Orange County Transportation Authority     OCTA Schedule         7246
#
#       tts_stop_name      gtfs_stop_name      stop_lat        stop_lon  \
# 17381          None   BAKE-SOUTH POINTE  33.659836000  -117.698669000
# 17382          None  EL TORO-NORMANDALE  33.654235000  -117.659354000
# 17383          None        NEWPORT-WASS  33.750429000  -117.810036000
#
#                                            website
# 17381  https://octa.net/current/google_transit.zip
# 17382  https://octa.net/current/google_transit.zip
# 17383  https://octa.net/current/google_transit.zip

# %%
octa_gtfs[["gtfs_stop_id", "gtfs_stop_name"]].drop_duplicates().sort_values(by="gtfs_stop_id").head()
# Out:
#       gtfs_stop_id     gtfs_stop_name
# 21015         0002  HASTER-ORANGEWOOD
# 18179         0003   HASTER-WAKEFIELD
# 21243         0004     HASTER-KATELLA
# 20726         0005    ANAHEIM-KATELLA
# 18917         0006   ANAHEIM-CERRITOS

# %% [markdown]
# #### Foothill Transit

# %%
foothill_ridership = df_ridership[df_ridership["organization_name"] == "Foothill Transit"]
foothill_ridership["stop_id"] = foothill_ridership["stop_id"].astype(int)
foothill_ridership.head(3)
# Out:
#        Unnamed: 0         record_id        dataset_id organization_name  \
# 69449       69449  593CBE13597D0721  1CCF9080DC015EB8  Foothill Transit
# 69450       69450  ED2D58C94F4FF910  1CCF9080DC015EB8  Foothill Transit
# 69451       69451  E95FB87C7CC5F712  1CCF9080DC015EB8  Foothill Transit
#
#            service_name route_id route_name direction  stop_id stop_name  \
# 69449  Foothill Transit      178        NaN         E       23       NaN
# 69450  Foothill Transit      178        NaN         E      555       NaN
# 69451  Foothill Transit      178        NaN         E      603       NaN
#
#         stop_lat    stop_lon  daily_boardings  daily_alightings  \
# 69449  34.034964 -117.919263              1.0               0.0
# 69450  34.030813 -117.914021             56.0              40.0
# 69451  34.029240 -117.910251              6.0               2.0
#
#        daily_total_ridership day_type daily_ridership_basis  start_date  \
# 69449                    NaN  weekday        reported_daily  2024-07-01
# 69450                    NaN  weekday        reported_daily  2024-07-01
# 69451                    NaN  weekday        reported_daily  2024-07-01
#
#          end_date gtfs_stop_id
# 69449  2024-07-01         <NA>
# 69450  2024-07-01         <NA>
# 69451  2024-07-01         <NA>

# %%
foothill_gtfs = df_gtfs[df_gtfs["organization_name"] == "Foothill Transit"]
foothill_gtfs.head(3)
# Out:
#                   schedule_feed_key       date organization_name  \
# 0  540b0c729962003092f3db62a6bbdd12 2026-02-04  Foothill Transit
# 1  540b0c729962003092f3db62a6bbdd12 2026-02-04  Foothill Transit
# 2  540b0c729962003092f3db62a6bbdd12 2026-02-04  Foothill Transit
#
#        service_name  gtfs_dataset_name gtfs_stop_id stop_code tts_stop_name  \
# 0  Foothill Transit  Foothill Schedule         1-a1         1          None
# 1  Foothill Transit  Foothill Schedule        10-a1        10          None
# 2  Foothill Transit  Foothill Schedule      1001-a1      1001          None
#
#                          gtfs_stop_name      stop_lat        stop_lon  \
# 0     Temple Ave and Diamond Bar Blvd E  34.040203000  -117.798028000
# 1       Orange Grove Ave and Glen Ave N  34.064129000  -117.781042000
# 2  Golden Springs Rd and Calbourne Dr E  33.994209000  -117.858221000
#
#                                              website
# 0  https://foothill3rdparty.rideralerts.com/mySto...
# 1  https://foothill3rdparty.rideralerts.com/mySto...
# 2  https://foothill3rdparty.rideralerts.com/mySto...

# %%
len(foothill_ridership["stop_id"].unique())
# Out:
# 1711

# %%
foothill_ridership[["stop_id", "stop_name", "stop_lat", "stop_lon"]].drop_duplicates().sort_values(by="stop_id")
# Out:
#         stop_id stop_name   stop_lat    stop_lon
# 70033         1       NaN  34.040203 -117.798028
# 75567         2       NaN  34.030259 -117.954117
# 75525         3       NaN  34.030282 -117.953686
# 92110         6       NaN  34.026183 -117.957879
# 78964         8       NaN  34.026087 -117.957574
# ...         ...       ...        ...         ...
# 69719      6119       NaN  34.134524 -118.073424
# 69988      6121       NaN  34.011100 -117.923186
# 70032      6122       NaN  34.011182 -117.922822
# 70421      6129       NaN  34.099993 -117.889165
# 220763     6130       NaN  34.107083 -117.872481
#
# [1716 rows x 4 columns]

# %%
foothill_gtfs["stop_code"] = foothill_gtfs["stop_code"].astype(int)
foothill_gtfs[["stop_code", "gtfs_stop_name", "stop_lat", "stop_lon"]].drop_duplicates().sort_values(by="stop_code")
# Out:
#       stop_code                       gtfs_stop_name      stop_lat  \
# 0             1    Temple Ave and Diamond Bar Blvd E  34.040203000
# 668           2       Hacienda Blvd and Temple Ave S  34.030259000
# 1250          3       Hacienda Blvd and Temple Ave N  34.030282000
# 1692          6       Hacienda Blvd and Nelson Ave S  34.026183000
# 1850          8       Hacienda Blvd and Nelson Ave N  34.026087000
# ...         ...                                  ...           ...
# 1711       6119  Rosemead Blvd and California Blvd E  34.134524000
# 1713       6121            Hurley St and Azusa Ave E  34.011100000
# 1714       6122            Hurley St and Azusa Ave W  34.011182000
# 1715       6129                Covina Transit Center  34.099993000
# 1717       6130            Grand Ave and Carter Dr E  34.107083000
#
#             stop_lon
# 0     -117.798028000
# 668   -117.954117000
# 1250  -117.953686000
# 1692  -117.957879000
# 1850  -117.957574000
# ...              ...
# 1711  -118.073424000
# 1713  -117.923186000
# 1714  -117.922822000
# 1715  -117.889165000
# 1717  -117.872481000
#
# [1726 rows x 4 columns]

# %% [markdown]
# #### Riverside Transit Agency

# %%
riverside_ridership = df_ridership[df_ridership["organization_name"] == "Riverside Transit Agency"]
riverside_ridership["stop_id"] = riverside_ridership["stop_id"].astype(int)
riverside_ridership.head(3)
# Out:
#          Unnamed: 0         record_id        dataset_id  \
# 1408114     1408114  FA62D2573CBD52E4  52A9DCDCDBA1CCD3
# 1408115     1408115  C04C14AE5D58539A  52A9DCDCDBA1CCD3
# 1408116     1408116  A28D487AEF8094D9  52A9DCDCDBA1CCD3
#
#                 organization_name       service_name route_id route_name  \
# 1408114  Riverside Transit Agency  Riverside Transit        1        NaN
# 1408115  Riverside Transit Agency  Riverside Transit        3        NaN
# 1408116  Riverside Transit Agency  Riverside Transit        3        NaN
#
#         direction  stop_id stop_name  ...    stop_lon avg_boardings  \
# 1408114   Inbound        0       NaN  ... -117.594376           NaN
# 1408115   Inbound        0       NaN  ...  -117.56432           NaN
# 1408116  Outbound        0       NaN  ...  -117.55464           NaN
#
#          avg_alightings  avg_ridership  day_type agg_basis  start_date  \
# 1408114             NaN           69.0   weekday     daily  2025-05-01
# 1408115             NaN            9.0   weekday     daily  2025-05-01
# 1408116             NaN            2.0   weekday     daily  2025-05-01
#
#            end_date gtfs_stop_id stop_loc_source
# 1408114  2025-05-01         <NA>             NaN
# 1408115  2025-05-01         <NA>             NaN
# 1408116  2025-05-01         <NA>             NaN
#
# [3 rows x 21 columns]

# %%
riverside_ridership[(riverside_ridership["stop_id"] != 0) & (riverside_ridership["stop_id"] != 888)][["stop_id", "stop_name", "stop_lat", "stop_lon"]].drop_duplicates().sort_values(by="stop_id").head(10)
# Out:
#          stop_id stop_name   stop_lat    stop_lon
# 1446062        2       NaN   33.80028 -117.226208
# 1408126     1004       NaN  33.879496   -117.5944
# 1799469     1004       NaN   33.88062 -117.594408
# 1571062     1004       NaN  33.879552 -117.594376
# 1572958     1004       NaN  33.895256 -117.594416
# 1797565     1004       NaN  33.879836 -117.594672
# 1431450     1004       NaN  33.879496 -117.594416
# 1795701     1004       NaN  33.880052 -117.594384
# 1583336     1004       NaN  33.984084 -117.594376
# 1429466     1004       NaN  33.984156 -117.594408

# %%
riverside_ridership[riverside_ridership["stop_id"] == 1004].drop_duplicates().sort_values(by="stop_id").head(5)
# Out:
#          Unnamed: 0         record_id        dataset_id  \
# 1408126     1408126  CE5B1BD1A26D1403  52A9DCDCDBA1CCD3
# 1704994     1704994  C855ADAE36B3169D  52A9DCDCDBA1CCD3
# 1706920     1706920  CDC12E0C4655F9A4  52A9DCDCDBA1CCD3
# 1708807     1708807  72C862E36FD5F76A  52A9DCDCDBA1CCD3
# 1710279     1710279  863DE36FA5FCEE06  52A9DCDCDBA1CCD3
#
#                 organization_name       service_name route_id route_name  \
# 1408126  Riverside Transit Agency  Riverside Transit        1        NaN
# 1704994  Riverside Transit Agency  Riverside Transit        1        NaN
# 1706920  Riverside Transit Agency  Riverside Transit        1        NaN
# 1708807  Riverside Transit Agency  Riverside Transit        1        NaN
# 1710279  Riverside Transit Agency  Riverside Transit        1        NaN
#
#         direction  stop_id stop_name  ...    stop_lon avg_boardings  \
# 1408126   Inbound     1004       NaN  ...   -117.5944           NaN
# 1704994   Inbound     1004       NaN  ... -117.594376           NaN
# 1706920   Inbound     1004       NaN  ... -117.594376           NaN
# 1708807   Inbound     1004       NaN  ... -117.594376           NaN
# 1710279   Inbound     1004       NaN  ... -117.610752           NaN
#
#          avg_alightings  avg_ridership  day_type agg_basis  start_date  \
# 1408126             NaN           16.0   weekday     daily  2025-05-01
# 1704994             NaN           31.0   weekday     daily  2025-01-23
# 1706920             NaN           19.0   weekday     daily  2025-01-24
# 1708807             NaN           14.0   weekend     daily  2025-01-25
# 1710279             NaN           26.0   weekend     daily  2025-01-26
#
#            end_date gtfs_stop_id stop_loc_source
# 1408126  2025-05-01         <NA>             NaN
# 1704994  2025-01-23         <NA>             NaN
# 1706920  2025-01-24         <NA>             NaN
# 1708807  2025-01-25         <NA>             NaN
# 1710279  2025-01-26         <NA>             NaN
#
# [5 rows x 21 columns]

# %%
sorted(riverside_ridership["stop_id"].astype(int).drop_duplicates())[:10]
# Out:
# [0, 2, 888, 1004, 1005, 1006, 1007, 1008, 1009, 1010]

# %% [markdown]
# riverside_gtfs = df_gtfs[df_gtfs["organization_name"] == "Riverside Transit Agency"]
# riverside_gtfs.head(3)

# %%
sorted(riverside_gtfs["gtfs_stop_id"].astype(int).drop_duplicates())[:10]
# Out:
# [3, 4, 5, 6, 8, 9, 10, 11, 12, 13]

# %%
riverside_gtfs[riverside_gtfs["gtfs_stop_id"] == '1004'].drop_duplicates().sort_values(by="gtfs_stop_id").head(10)
# Out:
#                       schedule_feed_key       date         organization_name  \
# 16928  0cdafe549ba239e0d7990f9dfbe03a78 2025-12-31  Riverside Transit Agency
#
#             service_name   gtfs_dataset_name gtfs_stop_id tts_stop_name  \
# 16928  Riverside Transit  Riverside Schedule         1004          None
#
#                     gtfs_stop_name      stop_lat        stop_lon  \
# 16928  Moreno Beach + Via Del Lago  33.895190000  -117.178521000
#
#                                                  website
# 16928  https://www.riversidetransit.com/google_transi...

# %% [markdown]
# ### Join on stop code (Culver City)

# %% [markdown]
# Stop id Culver City provided matches stop code in GTFS (maybe used to be the same as stop id in old feed)
#
# **Conclusion:** Stop ID and Stop Code are 1:1 -> we could use stop code in GTFS to join "stop id" (which is actually stop code) in ridership data to map in gtfs stop id and coordinates.

# %%
culver_city_ridership = df_ridership[df_ridership["organization_name"] == "City of Culver City"]
culver_city_gtfs = df_gtfs[df_gtfs["organization_name"] == "City of Culver City"]

# %%
culver_city_ridership.head(3)
# Out:
#          Unnamed: 0         record_id        dataset_id    organization_name  \
# 1404675     1404675  929D56F1611AFDFE  313575E419A203CA  City of Culver City
# 1404676     1404676  00308B6C2F5A2D38  313575E419A203CA  City of Culver City
# 1404677     1404677  274C2A033748D677  313575E419A203CA  City of Culver City
#
#            service_name route_id              route_name direction stop_id  \
# 1404675  Culver CityBus        1  1-Washington Boulevard   Inbound     101
# 1404676  Culver CityBus        1  1-Washington Boulevard   Inbound     102
# 1404677  Culver CityBus        1  1-Washington Boulevard   Inbound     103
#
#                            stop_name  stop_lat  stop_lon  avg_boardings  \
# 1404675           WindwardAve/MainSt       NaN       NaN          111.2
# 1404676    Pacific Ave/N Venice Blvd       NaN       NaN           31.7
# 1404677  Washington Blvd/Pacific Ave       NaN       NaN           84.2
#
#          avg_alightings  avg_ridership day_type daily_ridership_basis  \
# 1404675             0.2            NaN  Weekday    reported_avg_daily
# 1404676             1.9            NaN  Weekday    reported_avg_daily
# 1404677             9.7            NaN  Weekday    reported_avg_daily
#
#          start_date    end_date gtfs_stop_id
# 1404675  2025-07-14  2025-08-25         <NA>
# 1404676  2025-07-14  2025-08-25         <NA>
# 1404677  2025-07-14  2025-08-25         <NA>

# %%
culver_city_gtfs.head(3)
# Out:
#                      schedule_feed_key       date    organization_name  \
# 6032  90a34032bdea10f106a3922133c46444 2026-02-03  City of Culver City
# 6033  90a34032bdea10f106a3922133c46444 2026-02-03  City of Culver City
# 6034  90a34032bdea10f106a3922133c46444 2026-02-03  City of Culver City
#
#         service_name     gtfs_dataset_name gtfs_stop_id stop_code  \
# 6032  Culver CityBus  Culver City Schedule           10       107
# 6033  Culver CityBus  Culver City Schedule           11       108
# 6034  Culver CityBus  Culver City Schedule          119       201
#
#      tts_stop_name                  gtfs_stop_name      stop_lat  \
# 6032          None      Washington Blvd/Wilson Ave  33.984934000
# 6033          None      Washington Blvd/Oxford Ave  33.986364000
# 6034          None  Venice High School/Venice Blvd  33.998074000
#
#             stop_lon                                         website
# 6032  -118.457152000  https://web.culvercity.org/gtfs/gtfsexport.zip
# 6033  -118.454940000  https://web.culvercity.org/gtfs/gtfsexport.zip
# 6034  -118.444243000  https://web.culvercity.org/gtfs/gtfsexport.zip

# %%
# check if stop id and stop code are one to one
culver_city_gtfs.groupby(by="gtfs_stop_id")["stop_code"].nunique().reset_index(name="num_stop_code").sort_values(by="num_stop_code", ascending=False).head(3)
# Out:
#     gtfs_stop_id  num_stop_code
# 0             10              1
# 1             11              1
# 284          624              1

# %%
culver_city_gtfs.groupby(by="stop_code")["gtfs_stop_id"].nunique().reset_index(name="num_stop_id").sort_values(by="num_stop_id", ascending=False).head(3)
# Out:
#     stop_code  num_stop_id
# 0         101            1
# 1         102            1
# 284       617            1

# %%
culver_city_ridership[["stop_id", "stop_name"]].drop_duplicates().sort_values(by="stop_id").head(5)
# Out:
#         stop_id                    stop_name
# 1404675     101           WindwardAve/MainSt
# 1404676     102    Pacific Ave/N Venice Blvd
# 1404677     103  Washington Blvd/Pacific Ave
# 1404678     104    Washington Blvd/Via Dolce
# 1404679     105   Washington Blvd/Via Marina

# %%
culver_city_gtfs[["stop_code", "gtfs_stop_id", "gtfs_stop_name"]].drop_duplicates().sort_values(by="stop_code").head(5)
# Out:
#      stop_code gtfs_stop_id               gtfs_stop_name
# 6189       101            4         Windward Ave/Main St
# 6218       102            5    Pacific Ave/N Venice Blvd
# 6294       103            6  Washington Blvd/Pacific Ave
# 6391       104            7    Washington Blvd/Via Dolce
# 6438       105            8   Washington Blvd/Via Marina
