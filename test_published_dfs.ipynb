# %% [markdown]
# Check published files
#
# * should be able to read geojson in

# %%
from ridership_utils import utils

GCS_FILE_PATH = "gs://calitp-analytics-data/data-analyses/transit-ridership-analytics/"
PROCESSED_GCS = f"{GCS_FILE_PATH}processed/"

# %%
# test.geojson is the same as dim_stops_with_feed_service
df = utils.read_geojson(
    f"{PROCESSED_GCS}publish/",
    "test",
)

# %%
df.head()
# Out:
#                                 key                          feed_key stop_id  \
# 0  5e9351614aba649b95b6d6bc4bcc95c5  f88919081c15e52e44adaf0ba48e6dbc      95
# 1  fd015c94eeb7bea2ce7dfa11890a8c01  f88919081c15e52e44adaf0ba48e6dbc      86
# 2  f22798a6583ead5386230877befd3982  f88919081c15e52e44adaf0ba48e6dbc     531
# 3  378315c1ce33f1954e681dfe4057cb47  f88919081c15e52e44adaf0ba48e6dbc      10
# 4  c506d9ffa21d461ec0bbb2b519a5e857  f88919081c15e52e44adaf0ba48e6dbc     539
#
#                     stop_name stop_code           schedule_name  \
# 0           Hwy 111 at Arabia        95  SunLine Avail Schedule
# 1        Washington at Ave 50        86  SunLine Avail Schedule
# 2           Jackson at Ave 44       531  SunLine Avail Schedule
# 3  Palm Canyon at Via Escuela        10  SunLine Avail Schedule
# 4        Hwy 111 at San Pablo       539  SunLine Avail Schedule
#
#   service_date_start service_date_end                     geometry
# 0         2023-04-06       2023-05-03  POINT (-116.22452 33.71472)
# 1         2023-04-06       2023-05-03  POINT (-116.29497 33.68504)
# 2         2023-04-06       2023-05-03  POINT (-116.21642 33.72905)
# 3         2023-04-06       2023-05-03  POINT (-116.54797 33.84817)
# 4         2023-04-06       2023-05-03  POINT (-116.38214 33.72120)
